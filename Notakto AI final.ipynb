# %%
# line function to print a line
def line(iterable, board_list, board_num):
    for num in board_num:
        if num == '':
            continue
            
        for i in iterable:
            
            for j in range(2,-1,-1):
                if str(board_num[j]).isdecimal():
                    x = j
                    break
            
            if (num == x) and (i == 2 or i == 5 or i == 8):
                print(board_list[num][i], end = '\n')
            elif i == 2 or i == 5 or i == 8:
                print(board_list[num][i], end = '  ')
            else:
                print(board_list[num][i], end = ' ')
            
            
# board function to print the board
def board(board_list, board_marker):
## printing the board marker
    for i in range(len(board_marker)):
        
        for j in range(2,-1,-1):
                if str(board_num[j]).isdecimal():
                    x = j
                    break
                    
        if i != x and board_marker[i] != '':
            print(f'{board_marker[i]:<7}', end = '')
        else:
            print(board_marker[i],end = '')
    print()
    line((0,1,2), board_list, board_num)
    line((3,4,5), board_list, board_num)
    line((6,7,8), board_list, board_num)

    
# change board list function to mutate the board_list in a given index to X    
def change_board_list(move, board_list):
    if move[0] == 'A':
        board_list[0][int(move[1])] = 'X'
    elif move[0] == 'B':
        board_list[1][int(move[1])] = 'X'
    elif move[0] == 'C':
        board_list[2][int(move[1])] = 'X'
        

# delete board_function to delete part of a board which is dead
def delete_board(index):
    board_list[index] = ['', '', '', '', '', '', '', '', '']
    board_marker[index] = ''
    board_num[index] = ''
    
    
# check win function to specify winning conditions
def check_win(board_list, board_num):
    for i in board_num:
        if i != '':
            if (board_list[i][0] == board_list[i][1] == board_list[i][2] == 'X'  or board_list[i][3] == board_list[i][4] == board_list[i][5] == 'X' or board_list[i][6] == board_list[i][7] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][3] == board_list[i][6] == 'X' or board_list[i][1] == board_list[i][4] == board_list[i][7] == 'X' or board_list[i][2] == board_list[i][5] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][4] == board_list[i][8] == 'X' or board_list[i][6] == board_list[i][4] == board_list[i][2] == 'X'):
                delete_board(i)
                return True
        

# check input invalidity 
def input_check(move,used_move,board_marker):
    if move not in ('A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8'):
        return True
    if move in used_move:
        return True
    if move[0] not in board_marker:
        return True

# %%
def scissors_move(board_list):
    for i in range(3):
        if board_list[i][4] != 'X' and board_list[i] != ['', '', '', '', '', '', '', '', '']:
            if board_list[i][1] == 'X' and board_list[i][3] == 'X' and board_list[i][8] != 'X': 
                if i == 0:
                    return 'A8'
                elif i == 1:
                    return 'B8'
                elif i == 2:
                    return 'C8'
            elif board_list[i][1] == 'X' and board_list[i][3] != 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A3'
                elif i == 1:
                    return 'B3'
                elif i == 2:
                    return 'C3'
            elif board_list[i][1] != 'X' and board_list[i][3] == 'X' and board_list[i][8] == 'X': 
                if i == 0:
                    return 'A1'
                elif i == 1:
                    return 'B1'
                elif i == 2:
                    return 'C1'
            elif board_list[i][1] == 'X' and board_list[i][5] == 'X' and board_list[i][6] != 'X': 
                if i == 0:
                    return 'A6'
                elif i == 1:
                    return 'B6'
                elif i == 2:
                    return 'C6'
            elif board_list[i][1] == 'X' and board_list[i][5] != 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A5'
                elif i == 1:
                    return 'B5'
                elif i == 2:
                    return 'C5'
            elif board_list[i][1] != 'X' and board_list[i][5] == 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A1'
                elif i == 1:
                    return 'B1'
                elif i == 2:
                    return 'C1'
            elif board_list[i][3] == 'X' and board_list[i][7] == 'X' and board_list[i][2] != 'X':
                if i == 0:
                    return 'A2'
                elif i == 1:
                    return 'B2'
                elif i == 2:
                    return 'C2'
            elif board_list[i][3] == 'X' and board_list[i][7] != 'X' and board_list[i][2] == 'X':
                if i == 0:
                    return 'A7'
                elif i == 1:
                    return 'B7'
                elif i == 2:
                    return 'C7'
            elif board_list[i][3] != 'X' and board_list[i][7] == 'X' and board_list[i][2] == 'X':
                if i == 0:
                    return 'A3'
                elif i == 1:
                    return 'B3'
                elif i == 2:
                    return 'C3'
            elif board_list[i][0] == 'X' and board_list[i][5] == 'X' and board_list[i][7] != 'X': 
                if i == 0:
                    return 'A7'
                elif i == 1:
                    return 'B7'
                elif i == 2:
                    return 'C7'
            elif board_list[i][0] == 'X' and board_list[i][5] != 'X' and board_list[i][7] == 'X': 
                if i == 0:
                    return 'A5'
                elif i == 1:
                    return 'B5'
                elif i == 2:
                    return 'C5'
            elif board_list[i][0] != 'X' and board_list[i][5] == 'X' and board_list[i][7] == 'X': 
                if i == 0:
                    return 'A0'
                elif i == 1:
                    return 'B0'
                elif i == 2:
                    return 'C0'


def sacrifice_if_there_is_x_in_centre(board_list):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
            
        elif board_list[i][1] == 'X' and board_list[i][4] == 'X':
            if i == 0: 
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
            
        elif board_list[i][2] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
            
        elif board_list[i][3] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
            
        elif board_list[i][5] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 2:
                return 'C3'
        
        elif board_list[i][6] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
        
        elif board_list[i][7] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
        
        elif board_list[i][8] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
    
    
def sacrifice_if_no_x_in_centre(board_list):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][1] == 'X' and board_list[i][2] != 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
        elif board_list[i][0] == 'X' and board_list[i][1] != 'X' and board_list[i][2] == 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
        elif board_list[i][0] != 'X' and board_list[i][1] == 'X' and board_list[i][2] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
            
        elif board_list[i][0] == 'X' and board_list[i][3] == 'X' and board_list[i][6] != 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
        elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and board_list[i][6] == 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 2:
                return 'C3'
        elif board_list[i][0] != 'X' and board_list[i][3] == 'X' and board_list[i][6] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
            
        elif board_list[i][2] == 'X' and board_list[i][5] == 'X' and board_list[i][8] != 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
        elif board_list[i][2] == 'X' and board_list[i][5] != 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
        elif board_list[i][2] != 'X' and board_list[i][5] == 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
            
        elif board_list[i][6] == 'X' and board_list[i][7] == 'X' and board_list[i][8] != 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
        elif board_list[i][6] == 'X' and board_list[i][7] != 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
        elif board_list[i][6] != 'X' and board_list[i][7] == 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
    
        elif board_list[i][1] == 'X' and board_list[i][4] != 'X' and board_list[i][7] == 'X':
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            elif i == 2:
                return 'C4'
        
        elif board_list[i][3] == 'X' and board_list[i][4] != 'X' and board_list[i][5] == 'X':
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            elif i == 2:
                return 'C4'
        
        elif board_list[i][0] == 'X' and board_list[i][4] != 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            elif i == 2:
                return 'C4'   
        
        elif board_list[i][2] == 'X' and board_list[i][4] != 'X' and board_list[i][6] == 'X':
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            elif i == 2:
                return 'C4'
        

def board_count(board_num):
    counter = 0
    for i in board_num:
        if i == '':
            continue
        else:
            counter += 1
    return counter

def count_x_in_centre(board_list):
    counter = []
    for i in board_list:
        if i == ['', '', '', '', '', '', '', '', '']:
            pass
        elif i[4] != 'X':
            counter.append(False)
        elif i[4] == 'X':
            counter.append(True)
    return counter


def make_board_for_sacrifice(move, board_list):
    lst = []
    i = move[0]
    if i == 'A':
        x = 0
    elif i =='B':
        x = 1
    elif i == 'C':
        x = 2
    print(x)
    for j in range(len(board_list)):
        if j == x:
            lst.append(board_list[j])
        else:
            lst.append(['', '', '', '', '', '', '', '', ''])
    return lst

def count_x_in_a_board(board_list):
    counter = 0
    for board in board_list:
        for i in board:
            if i == 'X':
                counter += 1
                
    return counter

def scissors_in_board(board_list):
    for i in range(3):
        if board_list[i] == [0, 'X', 2, 'X', 4, 5, 6, 7, 'X'] or board_list[i] == [0, 'X', 2, 3, 4, 'X', 'X', 7, 8] or board_list[i] == [0, 1, 'X', 'X', 4, 5, 6, 'X', 8] or board_list[i] == ['X', 1, 2, 3, 4, 'X', 6, 'X', 8]:
            return True

# %%
def oneboard(board_list, used_move):
    
    board_alphabet = move[0]
    if board_alphabet == 'A':
        i = 0
    elif board_alphabet == 'B':
        i = 1
    elif board_alphabet == 'C':
        i = 2

    my_dict = {0: 'A', 1: 'B', 2: 'C'}

    if board_list[i][4] == 'X':

        if (board_list[i][0] == 'X') and (board_list[i][1] != 'X') and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][1] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][1] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][2] == 'X' and board_list[i][1] != 'X' and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][2] == 'X' and board_list[i][5] != 'X'and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'

        if board_list[i][3] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'
        elif board_list[i][3] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][5] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][5] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'

        if board_list[i][6] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][6] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][7] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'
        elif board_list[i][7] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'

        if board_list[i][8] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][8] == 'X' and board_list[i][5] != 'X' and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'
    for i in range(3):
        if board_list[i][4] != 'X' and board_list[i] != ['', '', '', '', '', '', '', '', ''] and not scissors_in_board(board_list):
            if board_list[i][0] == 'X' and board_list[i][8] != 'X':
                return my_dict[i] + '8'
            elif board_list[i][1] == 'X' and board_list[i][7] != 'X':
                return my_dict[i] + '7'
            elif board_list[i][2] == 'X'and board_list[i][6] != 'X':
                return my_dict[i] + '6'
            elif board_list[i][3] == 'X'and board_list[i][5] != 'X':
                return my_dict[i] + '5'
            elif board_list[i][5] == 'X'and board_list[i][3] != 'X':
                return my_dict[i] + '3'
            elif board_list[i][6] == 'X'and board_list[i][2] != 'X':
                return my_dict[i] + '2'
            elif board_list[i][7] == 'X'and board_list[i][1] != 'X':
                return my_dict[i] + '1'
            elif board_list[i][8] == 'X'and board_list[i][0] != 'X':
                return my_dict[i] + '0'
        
        elif board_list[i] == [0, 'X', 2, 'X', 4, 5, 6, 7, 'X']:
            return my_dict[i] + '0'
        elif board_list[i] == [0, 'X', 2, 3, 4, 'X', 'X', 7, 8]:
            return my_dict[i] + '2'
        elif board_list[i] == [0, 1, 'X', 'X', 4, 5, 6, 'X', 8]:
            return my_dict[i] + '6'
        elif board_list[i] == ['X', 1, 2, 3, 4, 'X', 6, 'X', 8]:
            return my_dict[i] + '8'
        elif board_list[i] == [0, 'X', 2, 3, 4, 'X', 'X', 7, 8]:
            return my_dict[i] + '2'
        
        elif board_list[i] == ['X', 'X', 2, 'X', 4, 'X', 6, 7, 'X']:
            return my_dict[i] + '7'
        elif board_list[i] == ['X', 'X', 2, 'X', 4, 5, 6, 'X', 'X']:
            return my_dict[i] + '5'
        
        elif board_list[i] == [0, 'X', 'X', 'X', 4, 'X', 'X', 7, 8]:
            return my_dict[i] + '7'
        elif board_list[i] == [0, 'X', 'X', 3, 4, 'X', 'X', 'X', 8]:
            return my_dict[i] + '3'
        
        elif board_list[i] == [0, 'X', 'X', 'X', 4, 5, 'X', 'X', 8]:
            return my_dict[i] + '5'
        elif board_list[i] == [0, 1, 'X', 'X', 4, 'X', 'X', 'X', 8]:
            return my_dict[i] + '1'
        
        elif board_list[i] == ['X', 1, 2, 'X', 4, 'X', 6, 'X', 'X']:
            return my_dict[i] + '1'
        elif board_list[i] == ['X', 'X', 2, 3, 4, 'X', 6, 'X', 'X']:
            return my_dict[i] + '3'
        
        
        
def twoboard(used_move):

    for i in range(len(board_list)):
        if board_list[i] == [0, 1, 2, 3, 4, 5, 6, 7, 8]:
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            else:
                return 'C4'
    
    if count_x_in_centre(board_list) == [True, True]:
        mylist = make_board_for_sacrifice(move, board_list)
        if sacrifice_if_there_is_x_in_centre (mylist)!= None:
            return sacrifice_if_there_is_x_in_centre(mylist)
        
    elif count_x_in_centre(board_list) == [True, False] or count_x_in_centre(board_list) == [False, True]:
        # play in the one with center x
        if move[0] + '4' in used_move:
            return oneboard(board_list, used_move)
        # play in the one with no center x
        else:
            new_board = []
            for i in board_list:
                if i[4] != 'X':
                    new_board.append(i)
                elif i[4] == 'X':
                    new_board.append(['', '', '', '', '', '', '', '', ''])
                    
            if sacrifice_if_no_x_in_centre(new_board) != None:
                return sacrifice_if_no_x_in_centre(new_board)
            else:
                return scissors_move(board_list)    
            

def threeboard():
    
    if move_count == 0:
        return 'A4'

    if move_count == 1 and move[0] == 'A':
        return sacrifice_if_there_is_x_in_centre(board_list) 
    if move_count == 1 and used_move[-1][0] == 'B':
        return 'C4'
    if move_count == 1 and used_move[-1][0] == 'C':
        return 'B4'
    
    if move_count >1 and sacrifice_if_there_is_x_in_centre(board_list) != None:
        return sacrifice_if_there_is_x_in_centre(board_list)
    elif move_count >1 and sacrifice_if_no_x_in_centre(board_list) != None:
        return sacrifice_if_no_x_in_centre(board_list)
    
    
    if move[0] == 'A':
        mymove = 0
    elif move[0] == 'B':
        mymove = 1
    else:
        mymove = 2
    
    centre = count_x_in_centre(board_list)
    if move_count == 2 and centre == [True, True, True]:
        return sacrifice_if_there_is_x_in_centre(board_list)
    elif move_count >= 2 and (centre == [True, False, True] or centre == [True, True, False]):
        
        if centre[mymove] == True:
            return sacrifice_if_there_is_x_in_centre(board_list)
        else:
            if sacrifice_if_no_x_in_centre(board_list) != None:
                return sacrifice_if_no_x_in_centre(board_list)
            else:
                return scissors_move(board_list)

# %%
import random
board_list = []
for _ in range(3):
    board_list.append([num for num in range(9)])

board_marker = ['A', 'B', 'C']

board_num = [0,1,2]

used_move = []

move_count = 0


while True: 
    # AI MOVE
    if board_count(board_num) == 3:
        move = threeboard()
    elif board_count(board_num) == 2:
        move = twoboard(used_move)
    elif board_count(board_num) == 1:
        move = oneboard(board_list,used_move)

    if move == None:
        while True:
            move = random.choice(('A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8'))

            if input_check(move,used_move,board_marker):
                pass
            else:
                break

    board(board_list, board_marker)

    print('Player 1:', move)

    change_board_list(move, board_list)

    check_win(board_list, board_num)

    used_move.append(move)
    
    print()
    print(f'board_list: {board_list}')
    print(f'board_num: {board_num}' )
    print(f'used_move: {used_move}')
    print(f'move_count: {move_count}')
    print(count_x_in_centre(board_list))
    print("move: " + move)
    print()
    
    move_count += 1

    if board_count(board_num) == 0:
        print('Player 2 wins game')
        break
        
    # player 2 move
    board(board_list, board_marker)

    while True:
        move = input("Player 2: ")
        
        if input_check(move,used_move,board_marker):
            print('Invalid move, please input again')
            pass
        else:
            used_move.append(move)
            break
    
    change_board_list(move, board_list)

    check_win(board_list, board_num)
    
    print()
    print(f'board_list: {board_list}')
    print(f'board_num: {board_num}' )
    print(f'used_move: {used_move}')
    print(f'move_count: {move_count}')
    print(count_x_in_centre(board_list))
    print("move: " + move)
    print()

    if board_count(board_num) == 0:
        print('Player 1 wins game')
        break
# Out:
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-403-8ddf985cc43e> in <module>
#      60
#      61     while True:
# ---> 62         move = input("Player 2: ")
#      63
#      64         if input_check(move,used_move,board_marker):
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
board_list = [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
used_move = ['A4', 'B0', 'C4', 'C0', 'C8', 'A1', 'A6', 'A0', 'A5', 'A2', 'B4']
scissors_in_board(board_list)
# Out:
# True

# %%
def addNumbers(phonebook, name, phones):
    if name not in phonebook:
        phonebook[name] = []
    phonebook[name].extend(phones)


def show(phonebook,command):
    if command[1] not in phonebook:
        print(command[1] + ' not found')
    else:
        print (phonebook[command[1]])

    
def find(phonebook,command):
    for i in phonebook:
        if command[1] in phonebook[i]:
            print(i)
            

def main():
    phonebook = {} 
    command = input().split() 
    
    while (command[0] != 'END'): 
        print('command', command)
        
        if command[0] == 'ADD':
            add(phonebook, command)
        elif command[0] == 'SHOW':
            show(phonebook, command)
        elif command[0] == 'FIND':
            find(phonebook,command)

        print('phonebook', phonebook)
        
        command = input().split()

main()

# %%
my_dict = {2:3, 5:6, 8:9}
my_new_dict = dict(zip(my_dict.values(), my_dict.keys()))
my_new_dict
# Out:
# {3: 2, 6: 5, 9: 8}

# %%
phonebook = {'KEVIN': ['123']}
x = phonebook.values()
for i in x:
    print(i)
# Out:
# ['123']

# %%
def f():
    name = 'Kevin'
    return f'hello {name}'

f()
# Out:
# 'hello Kevin'

# %%
my_dict = {2:[12,23], 5:6, 8:9}
for i in my_dict.values():
    print(i)
# Out:
# [12, 23]
# 6
# 9

# %%
'1'.split()
# Out:
# ['kevin']

# %%
import random
player_1_win, player_2_win = 0,0
for _ in range(100):
    board_list = []
    for _ in range(3):
        board_list.append([num for num in range(9)])

    board_marker = ['A', 'B', 'C']

    board_num = [0,1,2]

    used_move = []

    move_count = 0

    
    while True: 
        # AI MOVE
        if board_count(board_num) == 3:
            move = threeboard()
        elif board_count(board_num) == 2:
            move = twoboard(used_move)
        elif board_count(board_num) == 1:
            move = oneboard(board_list,used_move)
        
        if move == None:
            while True:
                move = random.choice(('A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8'))

                if input_check(move,used_move,board_marker):
                    pass
                else:
                    break
        
        board(board_list, board_marker)

        print('Player 1:', move)

        change_board_list(move, board_list)

        check_win(board_list, board_num)

        used_move.append(move)
        print()
        print(f'board_list: {board_list}')
        print(f'board_num: {board_num}' )
        print(f'used_move: {used_move}')
        print(f'move_count: {move_count}')
        print(count_x_in_centre(board_list))
        print("move: " + move)
        print()
        move_count += 1
        
        if board_count(board_num) == 0:
            print('Player 2 wins game')
            player_2_win += 1
            break
        # player 2 move
        board(board_list, board_marker)

        while True:
            #move = input("Player 2: ")
            move = random.choice(('A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8'))

            if input_check(move,used_move,board_marker):
                print('Invalid move, please input again')
                pass
            else:
                used_move.append(move)
                break
        print(print('Player 2:', move))
        change_board_list(move, board_list)

        check_win(board_list, board_num)
        print()
        print(f'board_list: {board_list}')
        print(f'board_num: {board_num}' )
        print(f'used_move: {used_move}')
        print(f'move_count: {move_count}')
        print(count_x_in_centre(board_list))
        print("move: " + move)
        print()
        if board_count(board_num) == 0:
            print('Player 1 wins game')
            player_1_win += 1
            break
print(player_1_win, player_2_win)
# Out:
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: B3
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B3']
# move_count: 1
# [True, False, False]
# move: B3
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  X 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: C4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B3', 'C4']
# move_count: 1
# [True, False, True]
# move: C4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  X 4 5  3 X 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A7
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7']
# move_count: 2
# [True, False, True]
# move: A7
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  X 4 5  3 X 5
# 6 X 8  6 7 8  6 7 8
# Player 1: A1
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1']
# move_count: 2
# [False, True]
# move: A1
#
# B      C
# 0 1 2  0 1 2
# X 4 5  3 X 5
# 6 7 8  6 7 8
# Player 2: B2
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2']
# move_count: 3
# [False, True]
# move: B2
#
# B      C
# 0 1 X  0 1 2
# X 4 5  3 X 5
# 6 7 8  6 7 8
# Player 1: B7
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 'X', 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7']
# move_count: 3
# [False, True]
# move: B7
#
# B      C
# 0 1 X  0 1 2
# X 4 5  3 X 5
# 6 X 8  6 7 8
# Invalid move, please input again
# Player 2: C1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 'X', 8], [0, 'X', 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7', 'C1']
# move_count: 4
# [False, True]
# move: C1
#
# B      C
# 0 1 X  0 X 2
# X 4 5  3 X 5
# 6 X 8  6 7 8
# Player 1: C6
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 'X', 8], [0, 'X', 2, 3, 'X', 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7', 'C1', 'C6']
# move_count: 4
# [False, True]
# move: C6
#
# B      C
# 0 1 X  0 X 2
# X 4 5  3 X 5
# 6 X 8  X 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 'X', 8], [0, 'X', 2, 3, 'X', 5, 'X', 7, 'X']]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7', 'C1', 'C6', 'C8']
# move_count: 5
# [False, True]
# move: C8
#
# B      C
# 0 1 X  0 X 2
# X 4 5  3 X 5
# 6 X 8  X 7 X
# Player 1: C5
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 'X', 8], [0, 'X', 2, 3, 'X', 'X', 'X', 7, 'X']]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7', 'C1', 'C6', 'C8', 'C5']
# move_count: 5
# [False, True]
# move: C5
#
# B      C
# 0 1 X  0 X 2
# X 4 5  3 X X
# 6 X 8  X 7 X
# Invalid move, please input again
# Player 2: B0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 'X', 4, 5, 6, 'X', 8], [0, 'X', 2, 3, 'X', 'X', 'X', 7, 'X']]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7', 'C1', 'C6', 'C8', 'C5', 'B0']
# move_count: 6
# [False, True]
# move: B0
#
# B      C
# X 1 X  0 X 2
# X 4 5  3 X X
# 6 X 8  X 7 X
# Player 1: B1
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 'X', 'X', 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7', 'C1', 'C6', 'C8', 'C5', 'B0', 'B1']
# move_count: 6
# [True]
# move: B1
#
# C
# 0 X 2
# 3 X X
# X 7 X
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C7
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'B3', 'C4', 'A7', 'A1', 'B2', 'B7', 'C1', 'C6', 'C8', 'C5', 'B0', 'B1', 'C7']
# move_count: 7
# []
# move: C7
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Invalid move, please input again
# Player 2: B1
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 'X', 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B1']
# move_count: 1
# [True, False, False]
# move: B1
#
# A      B      C
# 0 1 2  0 X 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: C4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 'X', 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B1', 'C4']
# move_count: 1
# [True, False, True]
# move: C4
#
# A      B      C
# 0 1 2  0 X 2  0 1 2
# 3 X 5  3 4 5  3 X 5
# 6 7 8  6 7 8  6 7 8
# Player 2: C8
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 'X', 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 'X']]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B1', 'C4', 'C8']
# move_count: 2
# [True, False, True]
# move: C8
#
# A      B      C
# 0 1 2  0 X 2  0 1 2
# 3 X 5  3 4 5  3 X 5
# 6 7 8  6 7 8  6 7 X
# Player 1: C0
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 'X', 2, 3, 4, 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, 1, '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0']
# move_count: 2
# [True, False]
# move: C0
#
# A      B
# 0 1 2  0 X 2
# 3 X 5  3 4 5
# 6 7 8  6 7 8
# Player 2: A7
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 'X', 2, 3, 4, 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, 1, '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0', 'A7']
# move_count: 3
# [True, False]
# move: A7
#
# A      B
# 0 1 2  0 X 2
# 3 X 5  3 4 5
# 6 X 8  6 7 8
# Player 1: A0
#
# board_list: [['X', 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 'X', 2, 3, 4, 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, 1, '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0', 'A7', 'A0']
# move_count: 3
# [True, False]
# move: A0
#
# A      B
# X 1 2  0 X 2
# 3 X 5  3 4 5
# 6 X 8  6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0', 'A7', 'A0', 'A1']
# move_count: 4
# [False]
# move: A1
#
# B
# 0 X 2
# 3 4 5
# 6 7 8
# Player 1: B7
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0', 'A7', 'A0', 'A1', 'B7']
# move_count: 4
# [False]
# move: B7
#
# B
# 0 X 2
# 3 4 5
# 6 X 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 'X', 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0', 'A7', 'A0', 'A1', 'B7', 'B8']
# move_count: 5
# [False]
# move: B8
#
# B
# 0 X 2
# 3 4 5
# 6 X X
# Player 1: B0
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 'X', 2, 3, 4, 5, 6, 'X', 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0', 'A7', 'A0', 'A1', 'B7', 'B8', 'B0']
# move_count: 5
# [False]
# move: B0
#
# B
# X X 2
# 3 4 5
# 6 X X
# Player 2: B4
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'B1', 'C4', 'C8', 'C0', 'A7', 'A0', 'A1', 'B7', 'B8', 'B0', 'B4']
# move_count: 6
# []
# move: B4
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A8
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 'X'], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A8']
# move_count: 1
# [True, False, False]
# move: A8
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 X  6 7 8  6 7 8
# Player 1: A0
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A8', 'A0']
# move_count: 1
# [False, False]
# move: A0
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 2: C3
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A8', 'A0', 'C3']
# move_count: 2
# [False, False]
# move: C3
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  X 4 5
# 6 7 8  6 7 8
# Player 1: B4
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4']
# move_count: 2
# [True, False]
# move: B4
#
# B      C
# 0 1 2  0 1 2
# 3 X 5  X 4 5
# 6 7 8  6 7 8
# Player 2: C6
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 'X', 4, 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4', 'C6']
# move_count: 3
# [True, False]
# move: C6
#
# B      C
# 0 1 2  0 1 2
# 3 X 5  X 4 5
# 6 7 8  X 7 8
# Player 1: C0
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4', 'C6', 'C0']
# move_count: 3
# [True]
# move: C0
#
# B
# 0 1 2
# 3 X 5
# 6 7 8
# Player 2: B8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4', 'C6', 'C0', 'B8']
# move_count: 4
# [True]
# move: B8
#
# B
# 0 1 2
# 3 X 5
# 6 7 X
# Player 1: B1
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 5, 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4', 'C6', 'C0', 'B8', 'B1']
# move_count: 4
# [True]
# move: B1
#
# B
# 0 X 2
# 3 X 5
# 6 7 X
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B2
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 'X', 3, 'X', 5, 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4', 'C6', 'C0', 'B8', 'B1', 'B2']
# move_count: 5
# [True]
# move: B2
#
# B
# 0 X X
# 3 X 5
# 6 7 X
# Player 1: B3
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 'X', 'X', 'X', 5, 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4', 'C6', 'C0', 'B8', 'B1', 'B2', 'B3']
# move_count: 5
# [True]
# move: B3
#
# B
# 0 X X
# X X 5
# 6 7 X
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B6
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'A8', 'A0', 'C3', 'B4', 'C6', 'C0', 'B8', 'B1', 'B2', 'B3', 'B6']
# move_count: 6
# []
# move: B6
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A3
# None
#
# board_list: [[0, 1, 2, 'X', 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A3']
# move_count: 1
# [True, False, False]
# move: A3
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# X X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A5
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5']
# move_count: 1
# [False, False]
# move: A5
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 2: B1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'B1']
# move_count: 2
# [False, False]
# move: B1
#
# B      C
# 0 X 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 1: C4
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4']
# move_count: 2
# [False, True]
# move: C4
#
# B      C
# 0 X 2  0 1 2
# 3 4 5  3 X 5
# 6 7 8  6 7 8
# Player 2: C1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 7, 8], [0, 'X', 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4', 'C1']
# move_count: 3
# [False, True]
# move: C1
#
# B      C
# 0 X 2  0 X 2
# 3 4 5  3 X 5
# 6 7 8  6 7 8
# Player 1: C6
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 7, 8], [0, 'X', 2, 3, 'X', 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4', 'C1', 'C6']
# move_count: 3
# [False, True]
# move: C6
#
# B      C
# 0 X 2  0 X 2
# 3 4 5  3 X 5
# 6 7 8  X 7 8
# Invalid move, please input again
# Player 2: C0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 7, 8], ['X', 'X', 2, 3, 'X', 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4', 'C1', 'C6', 'C0']
# move_count: 4
# [False, True]
# move: C0
#
# B      C
# 0 X 2  X X 2
# 3 4 5  3 X 5
# 6 7 8  X 7 8
# Player 1: C5
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 7, 8], ['X', 'X', 2, 3, 'X', 'X', 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4', 'C1', 'C6', 'C0', 'C5']
# move_count: 4
# [False, True]
# move: C5
#
# B      C
# 0 X 2  X X 2
# 3 4 5  3 X X
# 6 7 8  X 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B7
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 5, 6, 'X', 8], ['X', 'X', 2, 3, 'X', 'X', 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4', 'C1', 'C6', 'C0', 'C5', 'B7']
# move_count: 5
# [False, True]
# move: B7
#
# B      C
# 0 X 2  X X 2
# 3 4 5  3 X X
# 6 X 8  X 7 8
# Player 1: B4
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['X', 'X', 2, 3, 'X', 'X', 'X', 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4', 'C1', 'C6', 'C0', 'C5', 'B7', 'B4']
# move_count: 5
# [True]
# move: B4
#
# C
# X X 2
# 3 X X
# X 7 8
# Player 2: C7
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'A3', 'A5', 'B1', 'C4', 'C1', 'C6', 'C0', 'C5', 'B7', 'B4', 'C7']
# move_count: 6
# []
# move: C7
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A1
# None
#
# board_list: [[0, 'X', 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A1']
# move_count: 1
# [True, False, False]
# move: A1
#
# A      B      C
# 0 X 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A7
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7']
# move_count: 1
# [False, False]
# move: A7
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Invalid move, please input again
# Player 2: C4
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7', 'C4']
# move_count: 2
# [False, True]
# move: C4
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 X 5
# 6 7 8  6 7 8
# Player 1: B4
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4']
# move_count: 2
# [True, True]
# move: B4
#
# B      C
# 0 1 2  0 1 2
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Player 2: B7
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4', 'B7']
# move_count: 3
# [True, True]
# move: B7
#
# 1
# B      C
# 0 1 2  0 1 2
# 3 X 5  3 X 5
# 6 X 8  6 7 8
# Player 1: B1
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4', 'B7', 'B1']
# move_count: 3
# [True]
# move: B1
#
# C
# 0 1 2
# 3 X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C2
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 3, 'X', 5, 6, 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4', 'B7', 'B1', 'C2']
# move_count: 4
# [True]
# move: C2
#
# C
# 0 1 X
# 3 X 5
# 6 7 8
# Player 1: C7
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 3, 'X', 5, 6, 'X', 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4', 'B7', 'B1', 'C2', 'C7']
# move_count: 4
# [True]
# move: C7
#
# C
# 0 1 X
# 3 X 5
# 6 X 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 3, 'X', 5, 6, 'X', 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4', 'B7', 'B1', 'C2', 'C7', 'C8']
# move_count: 5
# [True]
# move: C8
#
# C
# 0 1 X
# 3 X 5
# 6 X X
# Player 1: C3
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 'X', 5, 6, 'X', 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4', 'B7', 'B1', 'C2', 'C7', 'C8', 'C3']
# move_count: 5
# [True]
# move: C3
#
# C
# 0 1 X
# X X 5
# 6 X X
# Invalid move, please input again
# Player 2: C0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'A1', 'A7', 'C4', 'B4', 'B7', 'B1', 'C2', 'C7', 'C8', 'C3', 'C0']
# move_count: 6
# []
# move: C0
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A1
# None
#
# board_list: [[0, 'X', 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A1']
# move_count: 1
# [True, False, False]
# move: A1
#
# A      B      C
# 0 X 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A7
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7']
# move_count: 1
# [False, False]
# move: A7
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Invalid move, please input again
# Player 2: B0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7', 'B0']
# move_count: 2
# [False, False]
# move: B0
#
# B      C
# X 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 1: C4
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4']
# move_count: 2
# [False, True]
# move: C4
#
# B      C
# X 1 2  0 1 2
# 3 4 5  3 X 5
# 6 7 8  6 7 8
# Player 2: C2
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 'X', 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4', 'C2']
# move_count: 3
# [False, True]
# move: C2
#
# B      C
# X 1 2  0 1 X
# 3 4 5  3 X 5
# 6 7 8  6 7 8
# Player 1: C7
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 'X', 3, 'X', 5, 6, 'X', 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4', 'C2', 'C7']
# move_count: 3
# [False, True]
# move: C7
# B      C
# X 1 2  0 1 X
# 3 4 5  3 X 5
# 6 7 8  6 X 8
# Player 2: C1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4', 'C2', 'C7', 'C1']
# move_count: 4
# [False]
# move: C1
#
# B
# X 1 2
# 3 4 5
# 6 7 8
# Player 1: B8
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 5, 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4', 'C2', 'C7', 'C1', 'B8']
# move_count: 4
# [False]
# move: B8
#
# B
# X 1 2
# 3 4 5
# 6 7 X
# Invalid move, please input again
# Player 2: B5
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 'X', 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4', 'C2', 'C7', 'C1', 'B8', 'B5']
# move_count: 5
# [False]
# move: B5
#
# B
# X 1 2
# 3 4 X
# 6 7 X
# Player 1: B3
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 'X', 4, 'X', 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4', 'C2', 'C7', 'C1', 'B8', 'B5', 'B3']
# move_count: 5
# [False]
# move: B3
#
# B
# X 1 2
# X 4 X
# 6 7 X
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B6
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'A1', 'A7', 'B0', 'C4', 'C2', 'C7', 'C1', 'B8', 'B5', 'B3', 'B6']
# move_count: 6
# []
# move: B6
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: C6
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C6']
# move_count: 1
# [True, False, False]
# move: C6
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  X 7 8
# Player 1: B4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C6', 'B4']
# move_count: 1
# [True, True, False]
# move: B4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 4 5
# 6 7 8  6 7 8  X 7 8
# Player 2: B1
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 'X', 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C6', 'B4', 'B1']
# move_count: 2
# [True, True, False]
# move: B1
#
# A      B      C
# 0 1 2  0 X 2  0 1 2
# 3 X 5  3 X 5  3 4 5
# 6 7 8  6 7 8  X 7 8
# Player 1: B7
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7']
# move_count: 2
# [True, False]
# move: B7
#
# A      C
# 0 1 2  0 1 2
# 3 X 5  3 4 5
# 6 7 8  X 7 8
# Player 2: A7
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7', 'A7']
# move_count: 3
# [True, False]
# move: A7
#
# A      C
# 0 1 2  0 1 2
# 3 X 5  3 4 5
# 6 X 8  X 7 8
# Player 1: A0
#
# board_list: [['X', 1, 2, 3, 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7', 'A7', 'A0']
# move_count: 3
# [True, False]
# move: A0
#
# A      C
# X 1 2  0 1 2
# 3 X 5  3 4 5
# 6 X 8  X 7 8
# Player 2: A8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7', 'A7', 'A0', 'A8']
# move_count: 4
# [False]
# move: A8
#
# C
# 0 1 2
# 3 4 5
# X 7 8
# Player 1: C2
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 3, 4, 5, 'X', 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7', 'A7', 'A0', 'A8', 'C2']
# move_count: 4
# [False]
# move: C2
#
# C
# 0 1 X
# 3 4 5
# X 7 8
# Player 2: C0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 3, 4, 5, 'X', 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7', 'A7', 'A0', 'A8', 'C2', 'C0']
# move_count: 5
# [False]
# move: C0
#
# C
# X 1 X
# 3 4 5
# X 7 8
# Player 1: C8
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 3, 4, 5, 'X', 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7', 'A7', 'A0', 'A8', 'C2', 'C0', 'C8']
# move_count: 5
# [False]
# move: C8
#
# C
# X 1 X
# 3 4 5
# X 7 X
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C7
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'C6', 'B4', 'B1', 'B7', 'A7', 'A0', 'A8', 'C2', 'C0', 'C8', 'C7']
# move_count: 6
# []
# move: C7
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: C4
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C4']
# move_count: 1
# [True, False, True]
# move: C4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 X 5
# 6 7 8  6 7 8  6 7 8
# Player 1: B4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C4', 'B4']
# move_count: 1
# [True, True, True]
# move: B4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 X 5
# 6 7 8  6 7 8  6 7 8
# Invalid move, please input again
# Player 2: B2
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 'X', 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C4', 'B4', 'B2']
# move_count: 2
# [True, True, True]
# move: B2
#
# A      B      C
# 0 1 2  0 1 X  0 1 2
# 3 X 5  3 X 5  3 X 5
# 6 7 8  6 7 8  6 7 8
# Player 1: B6
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'C4', 'B4', 'B2', 'B6']
# move_count: 2
# [True, True]
# move: B6
#
# A      C
# 0 1 2  0 1 2
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Player 2: C2
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 3, 'X', 5, 6, 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'C4', 'B4', 'B2', 'B6', 'C2']
# move_count: 3
# [True, True]
# move: C2
#
# 2
# A      C
# 0 1 2  0 1 X
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Player 1: C6
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C4', 'B4', 'B2', 'B6', 'C2', 'C6']
# move_count: 3
# [True]
# move: C6
#
# A
# 0 1 2
# 3 X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A1
# None
#
# board_list: [[0, 'X', 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C4', 'B4', 'B2', 'B6', 'C2', 'C6', 'A1']
# move_count: 4
# [True]
# move: A1
#
# A
# 0 X 2
# 3 X 5
# 6 7 8
# Player 1: A6
#
# board_list: [[0, 'X', 2, 3, 'X', 5, 'X', 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C4', 'B4', 'B2', 'B6', 'C2', 'C6', 'A1', 'A6']
# move_count: 4
# [True]
# move: A6
#
# A
# 0 X 2
# 3 X 5
# X 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A7
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'C4', 'B4', 'B2', 'B6', 'C2', 'C6', 'A1', 'A6', 'A7']
# move_count: 5
# []
# move: A7
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: C5
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 'X', 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C5']
# move_count: 1
# [True, False, False]
# move: C5
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 X
# 6 7 8  6 7 8  6 7 8
# Player 1: B4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 'X', 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C5', 'B4']
# move_count: 1
# [True, True, False]
# move: B4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 4 X
# 6 7 8  6 7 8  6 7 8
# Player 2: C4
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 'X', 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C5', 'B4', 'C4']
# move_count: 2
# [True, True, True]
# move: C4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 X X
# 6 7 8  6 7 8  6 7 8
# Player 1: C3
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, 1, '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3']
# move_count: 2
# [True, True]
# move: C3
#
# A      B
# 0 1 2  0 1 2
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B5
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 'X', 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, 1, '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3', 'B5']
# move_count: 3
# [True, True]
# move: B5
#
# 1
# A      B
# 0 1 2  0 1 2
# 3 X 5  3 X X
# 6 7 8  6 7 8
# Player 1: B3
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3', 'B5', 'B3']
# move_count: 3
# [True]
# move: B3
#
# A
# 0 1 2
# 3 X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A1
# None
#
# board_list: [[0, 'X', 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3', 'B5', 'B3', 'A1']
# move_count: 4
# [True]
# move: A1
#
# A
# 0 X 2
# 3 X 5
# 6 7 8
# Player 1: A6
#
# board_list: [[0, 'X', 2, 3, 'X', 5, 'X', 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3', 'B5', 'B3', 'A1', 'A6']
# move_count: 4
# [True]
# move: A6
#
# A
# 0 X 2
# 3 X 5
# X 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A0
# None
#
# board_list: [['X', 'X', 2, 3, 'X', 5, 'X', 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3', 'B5', 'B3', 'A1', 'A6', 'A0']
# move_count: 5
# [True]
# move: A0
#
# A
# X X 2
# 3 X 5
# X 7 8
# Player 1: A5
#
# board_list: [['X', 'X', 2, 3, 'X', 'X', 'X', 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3', 'B5', 'B3', 'A1', 'A6', 'A0', 'A5']
# move_count: 5
# [True]
# move: A5
#
# A
# X X 2
# 3 X X
# X 7 8
# Invalid move, please input again
# Player 2: A3
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'C5', 'B4', 'C4', 'C3', 'B5', 'B3', 'A1', 'A6', 'A0', 'A5', 'A3']
# move_count: 6
# []
# move: A3
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: C6
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C6']
# move_count: 1
# [True, False, False]
# move: C6
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  X 7 8
# Player 1: B4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C6', 'B4']
# move_count: 1
# [True, True, False]
# move: B4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 4 5
# 6 7 8  6 7 8  X 7 8
# Player 2: B3
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 'X', 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C6', 'B4', 'B3']
# move_count: 2
# [True, True, False]
# move: B3
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  X X 5  3 4 5
# 6 7 8  6 7 8  X 7 8
# Player 1: B5
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5']
# move_count: 2
# [True, False]
# move: B5
#
# A      C
# 0 1 2  0 1 2
# 3 X 5  3 4 5
# 6 7 8  X 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C8
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 'X', 7, 'X']]
# board_num: [0, '', 2]
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5', 'C8']
# move_count: 3
# [True, False]
# move: C8
#
# A      C
# 0 1 2  0 1 2
# 3 X 5  3 4 5
# 6 7 8  X 7 X
# Player 1: C7
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5', 'C8', 'C7']
# move_count: 3
# [True]
# move: C7
#
# A
# 0 1 2
# 3 X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A5
# None
#
# board_list: [[0, 1, 2, 3, 'X', 'X', 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5', 'C8', 'C7', 'A5']
# move_count: 4
# [True]
# move: A5
#
# A
# 0 1 2
# 3 X X
# 6 7 8
# Player 1: A6
#
# board_list: [[0, 1, 2, 3, 'X', 'X', 'X', 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5', 'C8', 'C7', 'A5', 'A6']
# move_count: 4
# [True]
# move: A6
#
# A
# 0 1 2
# 3 X X
# X 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A8
# None
#
# board_list: [[0, 1, 2, 3, 'X', 'X', 'X', 7, 'X'], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5', 'C8', 'C7', 'A5', 'A6', 'A8']
# move_count: 5
# [True]
# move: A8
#
# A
# 0 1 2
# 3 X X
# X 7 X
# Player 1: A1
#
# board_list: [[0, 'X', 2, 3, 'X', 'X', 'X', 7, 'X'], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5', 'C8', 'C7', 'A5', 'A6', 'A8', 'A1']
# move_count: 5
# [True]
# move: A1
#
# A
# 0 X 2
# 3 X X
# X 7 X
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A2
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'C6', 'B4', 'B3', 'B5', 'C8', 'C7', 'A5', 'A6', 'A8', 'A1', 'A2']
# move_count: 6
# []
# move: A2
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Invalid move, please input again
# Player 2: A2
# None
#
# board_list: [[0, 1, 'X', 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A2']
# move_count: 1
# [True, False, False]
# move: A2
#
# A      B      C
# 0 1 X  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A6
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A2', 'A6']
# move_count: 1
# [False, False]
# move: A6
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 2: C6
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A2', 'A6', 'C6']
# move_count: 2
# [False, False]
# move: C6
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  X 7 8
# Player 1: B4
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4']
# move_count: 2
# [True, False]
# move: B4
#
# B      C
# 0 1 2  0 1 2
# 3 X 5  3 4 5
# 6 7 8  X 7 8
# Player 2: B7
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4', 'B7']
# move_count: 3
# [True, False]
# move: B7
#
# B      C
# 0 1 2  0 1 2
# 3 X 5  3 4 5
# 6 X 8  X 7 8
# Player 1: B0
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4', 'B7', 'B0']
# move_count: 3
# [True, False]
# move: B0
#
# B      C
# X 1 2  0 1 2
# 3 X 5  3 4 5
# 6 X 8  X 7 8
# Player 2: C0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 'X', 8], ['X', 1, 2, 3, 4, 5, 'X', 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4', 'B7', 'B0', 'C0']
# move_count: 4
# [True, False]
# move: C0
#
# B      C
# X 1 2  X 1 2
# 3 X 5  3 4 5
# 6 X 8  X 7 8
# Player 1: C3
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4', 'B7', 'B0', 'C0', 'C3']
# move_count: 4
# [True]
# move: C3
#
# B
# X 1 2
# 3 X 5
# 6 X 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B3
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 'X', 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4', 'B7', 'B0', 'C0', 'C3', 'B3']
# move_count: 5
# [True]
# move: B3
#
# B
# X 1 2
# X X 5
# 6 X 8
# Player 1: B2
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 'X', 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4', 'B7', 'B0', 'C0', 'C3', 'B3', 'B2']
# move_count: 5
# [True]
# move: B2
#
# B
# X 1 X
# X X 5
# 6 X 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'A2', 'A6', 'C6', 'B4', 'B7', 'B0', 'C0', 'C3', 'B3', 'B2', 'B8']
# move_count: 6
# []
# move: B8
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: B3
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B3']
# move_count: 1
# [True, False, False]
# move: B3
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  X 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: C4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B3', 'C4']
# move_count: 1
# [True, False, True]
# move: C4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  X 4 5  3 X 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A6
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 'X', 7, 8], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A6']
# move_count: 2
# [True, False, True]
# move: A6
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  X 4 5  3 X 5
# X 7 8  6 7 8  6 7 8
# Player 1: A2
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2']
# move_count: 2
# [False, True]
# move: A2
#
# B      C
# 0 1 2  0 1 2
# X 4 5  3 X 5
# 6 7 8  6 7 8
# Invalid move, please input again
# Player 2: B2
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2']
# move_count: 3
# [False, True]
# move: B2
#
# B      C
# 0 1 X  0 1 2
# X 4 5  3 X 5
# 6 7 8  6 7 8
# Player 1: B7
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 4, 5, 6, 'X', 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7']
# move_count: 3
# [False, True]
# move: B7
#
# B      C
# 0 1 X  0 1 2
# X 4 5  3 X 5
# 6 X 8  6 7 8
# Player 2: B4
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 'X', 5, 6, 'X', 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7', 'B4']
# move_count: 4
# [True, True]
# move: B4
#
# 1
# B      C
# 0 1 X  0 1 2
# X X 5  3 X 5
# 6 X 8  6 7 8
# Player 1: B6
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7', 'B4', 'B6']
# move_count: 4
# [True]
# move: B6
#
# C
# 0 1 2
# 3 X 5
# 6 7 8
# Player 2: C8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7', 'B4', 'B6', 'C8']
# move_count: 5
# [True]
# move: C8
#
# C
# 0 1 2
# 3 X 5
# 6 7 X
# Player 1: C1
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 5, 6, 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7', 'B4', 'B6', 'C8', 'C1']
# move_count: 5
# [True]
# move: C1
#
# C
# 0 X 2
# 3 X 5
# 6 7 X
# Player 2: C6
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 5, 'X', 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7', 'B4', 'B6', 'C8', 'C1', 'C6']
# move_count: 6
# [True]
# move: C6
#
# C
# 0 X 2
# 3 X 5
# X 7 X
# Player 1: C5
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 'X', 'X', 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7', 'B4', 'B6', 'C8', 'C1', 'C6', 'C5']
# move_count: 6
# [True]
# move: C5
#
# C
# 0 X 2
# 3 X X
# X 7 X
# Invalid move, please input again
# Player 2: C0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'B3', 'C4', 'A6', 'A2', 'B2', 'B7', 'B4', 'B6', 'C8', 'C1', 'C6', 'C5', 'C0']
# move_count: 7
# []
# move: C0
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A5
# None
#
# board_list: [[0, 1, 2, 3, 'X', 'X', 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A5']
# move_count: 1
# [True, False, False]
# move: A5
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X X  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A3
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A5', 'A3']
# move_count: 1
# [False, False]
# move: A3
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 2: B3
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A5', 'A3', 'B3']
# move_count: 2
# [False, False]
# move: B3
#
# B      C
# 0 1 2  0 1 2
# X 4 5  3 4 5
# 6 7 8  6 7 8
# Player 1: C4
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# ...
# move_count: 3
# [True]
# move: B8
#
# C
# 0 1 2
# 3 X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C6
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 'X', 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'B4', 'C4', 'A7', 'A1', 'B0', 'B8', 'C6']
# move_count: 4
# [True]
# move: C6
#
# C
# 0 1 2
# 3 X 5
# X 7 8
# Player 1: C1
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 5, 'X', 7, 8]]
# board_num: ['', '', 2]
# used_move: ['A4', 'B4', 'C4', 'A7', 'A1', 'B0', 'B8', 'C6', 'C1']
# move_count: 4
# [True]
# move: C1
#
# C
# 0 X 2
# 3 X 5
# X 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 5, 'X', 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'B4', 'C4', 'A7', 'A1', 'B0', 'B8', 'C6', 'C1', 'C8']
# move_count: 5
# [True]
# move: C8
#
# C
# 0 X 2
# 3 X 5
# X 7 X
# Player 1: C5
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 'X', 'X', 7, 'X']]
# board_num: ['', '', 2]
# used_move: ['A4', 'B4', 'C4', 'A7', 'A1', 'B0', 'B8', 'C6', 'C1', 'C8', 'C5']
# move_count: 5
# [True]
# move: C5
#
# C
# 0 X 2
# 3 X X
# X 7 X
# Player 2: C2
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'B4', 'C4', 'A7', 'A1', 'B0', 'B8', 'C6', 'C1', 'C8', 'C5', 'C2']
# move_count: 6
# []
# move: C2
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A3
# None
#
# board_list: [[0, 1, 2, 'X', 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A3']
# move_count: 1
# [True, False, False]
# move: A3
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# X X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A5
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5']
# move_count: 1
# [False, False]
# move: A5
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 2: C0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], ['X', 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'C0']
# move_count: 2
# [False, False]
# move: C0
#
# B      C
# 0 1 2  X 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Player 1: B4
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['X', 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4']
# move_count: 2
# [True, False]
# move: B4
#
# B      C
# 0 1 2  X 1 2
# 3 X 5  3 4 5
# 6 7 8  6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['X', 'X', 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4', 'C1']
# move_count: 3
# [True, False]
# move: C1
#
# B      C
# 0 1 2  X X 2
# 3 X 5  3 4 5
# 6 7 8  6 7 8
# Player 1: C2
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4', 'C1', 'C2']
# move_count: 3
# [True]
# move: C2
#
# B
# 0 1 2
# 3 X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B3
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4', 'C1', 'C2', 'B3']
# move_count: 4
# [True]
# move: B3
#
# B
# 0 1 2
# X X 5
# 6 7 8
# Player 1: B2
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4', 'C1', 'C2', 'B3', 'B2']
# move_count: 4
# [True]
# move: B2
#
# B
# 0 1 X
# X X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 'X', 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4', 'C1', 'C2', 'B3', 'B2', 'B0']
# move_count: 5
# [True]
# move: B0
#
# B
# X 1 X
# X X 5
# 6 7 8
# Player 1: B7
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 'X', 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4', 'C1', 'C2', 'B3', 'B2', 'B0', 'B7']
# move_count: 5
# [True]
# move: B7
#
# B
# X 1 X
# X X 5
# 6 X 8
# Player 2: B1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'A3', 'A5', 'C0', 'B4', 'C1', 'C2', 'B3', 'B2', 'B0', 'B7', 'B1']
# move_count: 6
# []
# move: B1
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: C7
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 'X', 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C7']
# move_count: 1
# [True, False, False]
# move: C7
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 X 8
# Player 1: B4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 'X', 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C7', 'B4']
# move_count: 1
# [True, True, False]
# move: B4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 4 5
# 6 7 8  6 7 8  6 X 8
# Player 2: C6
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 'X', 'X', 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'C7', 'B4', 'C6']
# move_count: 2
# [True, True, False]
# move: C6
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 4 5
# 6 7 8  6 7 8  X X 8
# Player 1: C8
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, 1, '']
# used_move: ['A4', 'C7', 'B4', 'C6', 'C8']
# move_count: 2
# [True, True]
# move: C8
#
# A      B
# 0 1 2  0 1 2
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Player 2: A1
# None
#
# board_list: [[0, 'X', 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, 1, '']
# used_move: ['A4', 'C7', 'B4', 'C6', 'C8', 'A1']
# move_count: 3
# [True, True]
# move: A1
#
# 0
# A      B
# 0 X 2  0 1 2
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Player 1: A7
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'C7', 'B4', 'C6', 'C8', 'A1', 'A7']
# move_count: 3
# [True]
# move: A7
#
# B
# 0 1 2
# 3 X 5
# 6 7 8
# Player 2: B3
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'C7', 'B4', 'C6', 'C8', 'A1', 'A7', 'B3']
# move_count: 4
# [True]
# move: B3
#
# B
# 0 1 2
# X X 5
# 6 7 8
# Player 1: B2
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 'X', 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'C7', 'B4', 'C6', 'C8', 'A1', 'A7', 'B3', 'B2']
# move_count: 4
# [True]
# move: B2
#
# B
# 0 1 X
# X X 5
# 6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B6
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'C7', 'B4', 'C6', 'C8', 'A1', 'A7', 'B3', 'B2', 'B6']
# move_count: 5
# []
# move: B6
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A7
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A7']
# move_count: 1
# [True, False, False]
# move: A7
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 X 8  6 7 8  6 7 8
# Player 1: A1
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A7', 'A1']
# move_count: 1
# [False, False]
# move: A1
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 5
# 6 7 8  6 7 8
# Invalid move, please input again
# Player 2: C5
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 'X', 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A7', 'A1', 'C5']
# move_count: 2
# [False, False]
# move: C5
#
# B      C
# 0 1 2  0 1 2
# 3 4 5  3 4 X
# 6 7 8  6 7 8
# Player 1: B4
#
# board_list: [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 'X', 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4']
# move_count: 2
# [True, False]
# move: B4
#
# B      C
# 0 1 2  0 1 2
# 3 X 5  3 4 X
# 6 7 8  6 7 8
# Player 2: B0
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 'X', 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4', 'B0']
# move_count: 3
# [True, False]
# move: B0
#
# B      C
# X 1 2  0 1 2
# 3 X 5  3 4 X
# 6 7 8  6 7 8
# Player 1: B7
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 1, 2, 3, 4, 'X', 6, 7, 8]]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4', 'B0', 'B7']
# move_count: 3
# [True, False]
# move: B7
#
# B      C
# X 1 2  0 1 2
# 3 X 5  3 4 X
# 6 X 8  6 7 8
# Player 2: C8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 'X', 8], [0, 1, 2, 3, 4, 'X', 6, 7, 'X']]
# board_num: ['', 1, 2]
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4', 'B0', 'B7', 'C8']
# move_count: 4
# [True, False]
# move: C8
#
# B      C
# X 1 2  0 1 2
# 3 X 5  3 4 X
# 6 X 8  6 7 X
# Player 1: C2
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4', 'B0', 'B7', 'C8', 'C2']
# move_count: 4
# [True]
# move: C2
#
# B
# X 1 2
# 3 X 5
# 6 X 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B3
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 'X', 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4', 'B0', 'B7', 'C8', 'C2', 'B3']
# move_count: 5
# [True]
# move: B3
#
# B
# X 1 2
# X X 5
# 6 X 8
# Player 1: B2
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 'X', 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', 1, '']
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4', 'B0', 'B7', 'C8', 'C2', 'B3', 'B2']
# move_count: 5
# [True]
# move: B2
#
# B
# X 1 X
# X X 5
# 6 X 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: B8
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'A7', 'A1', 'C5', 'B4', 'B0', 'B7', 'C8', 'C2', 'B3', 'B2', 'B8']
# move_count: 6
# []
# move: B8
#
# Player 1 wins game
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 1: A4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# move_count: 0
# [True, False, False]
# move: A4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: B8
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 'X'], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B8']
# move_count: 1
# [True, False, False]
# move: B8
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 X  6 7 8
# Player 1: C4
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 'X'], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B8', 'C4']
# move_count: 1
# [True, False, True]
# move: C4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 X 5
# 6 7 8  6 7 X  6 7 8
# Player 2: B4
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 'X'], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'B8', 'C4', 'B4']
# move_count: 2
# [True, True, True]
# move: B4
#
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 X 5  3 X 5
# 6 7 8  6 7 X  6 7 8
# Player 1: B0
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0']
# move_count: 2
# [True, True]
# move: B0
#
# A      C
# 0 1 2  0 1 2
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Invalid move, please input again
# Invalid move, please input again
# Player 2: C1
# None
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 'X', 5, 6, 7, 8]]
# board_num: [0, '', 2]
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0', 'C1']
# move_count: 3
# [True, True]
# move: C1
#
# 2
# A      C
# 0 1 2  0 X 2
# 3 X 5  3 X 5
# 6 7 8  6 7 8
# Player 1: C7
#
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0', 'C1', 'C7']
# move_count: 3
# [True]
# move: C7
#
# A
# 0 1 2
# 3 X 5
# 6 7 8
# Player 2: A0
# None
#
# board_list: [['X', 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0', 'C1', 'C7', 'A0']
# move_count: 4
# [True]
# move: A0
#
# A
# X 1 2
# 3 X 5
# 6 7 8
# Player 1: A7
#
# board_list: [['X', 1, 2, 3, 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0', 'C1', 'C7', 'A0', 'A7']
# move_count: 4
# [True]
# move: A7
#
# A
# X 1 2
# 3 X 5
# 6 X 8
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Invalid move, please input again
# Player 2: A5
# None
#
# board_list: [['X', 1, 2, 3, 'X', 'X', 6, 'X', 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0', 'C1', 'C7', 'A0', 'A7', 'A5']
# move_count: 5
# [True]
# move: A5
#
# A
# X 1 2
# 3 X X
# 6 X 8
# Player 1: A6
#
# board_list: [['X', 1, 2, 3, 'X', 'X', 'X', 'X', 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: [0, '', '']
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0', 'C1', 'C7', 'A0', 'A7', 'A5', 'A6']
# move_count: 5
# [True]
# move: A6
#
# A
# X 1 2
# 3 X X
# X X 8
# Player 2: A1
# None
#
# board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# board_num: ['', '', '']
# used_move: ['A4', 'B8', 'C4', 'B4', 'B0', 'C1', 'C7', 'A0', 'A7', 'A5', 'A6', 'A1']
# move_count: 6
# []
# move: A1
#
# Player 1 wins game
# 100 0

# %%
def addNumbers(phonebook, name, phones):
    if name not in phonebook:
        phonebook[name] = []
    phonebook[name].extend(phones)
    


def show(phonebook,command, name):
    if name not in phonebook:
        print(name + ' not found')
    else:
        print (phonebook[name])


def find(phonebook,command, name):
    for key in phonebook:
        if name in phonebook[key]:
            return(key)
        else:
            return(name + ' not found')

used_name = []
used_phone = []
def main():
    phonebook = {} 
    command = input().split() 

    while (command[0] != 'END'): 
        name = command[1]
        phones = command[2:]
        phones.sort()
        phones.reverse()
        
        if command[0] == 'ADD':
            addNumbers(phonebook, name, phones)
        elif command[0] == 'SHOW':
            show(phonebook, command, name)
        elif command[0] == 'FIND':
            print(find(phonebook,command, name))
        #print('phonebook', phonebook)
        command = input().split()

main()
# Out:
# ADD KEVIN 123 124
# SHOW KEVIN
# ['124', '123']
# END

# %%
command = input().split() 
name = command[1]
phones = command[2:]
phones.sort()
phones.reverse()

phones
# Out:
# ADD KEVIN 123 124
# ['124', '123']

# %%
def find(phonebook, name):
    for key in phonebook:
        if name in phonebook[key]:
            return key
        if name not in phonebook[key]:
            return (name + ' not found')

# %%
phonebook = {"kevin": ['123'], "betty": ['234', '456'], 'ACA': ['124']}
name = '456'
lst = []
for key in phonebook:
    if name in (phonebook[key]):
        print(key)
        lst.append(key)
        
    print('lst', lst)
    if key not in lst:
        print('no key')
# Out:
# lst []
# no key
# betty
# lst ['betty']
# lst ['betty']
# no key

# %%
find(phonebook, name)
# Out:
# '234 not found'

# %%
command = input().split() 
phonebook = {} 

while (command[0] != 'END'): 
    name = str(command[1])
    print('name', name)
    phones = command[2:]
    print(phones)
    if command[0] == 'ADD':
        addNumbers(phonebook, name, phones)
    elif command[0] == 'SHOW':
        show(phonebook, command, name)
    elif command[0] == 'FIND':
        print(find(phonebook, name))
    print('phonebook', phonebook)
    command = input().split()
# Out:
# ADD KEVIN 123
# name KEVIN
# ['123']
# phonebook {'KEVIN': ['123']}
# ADD BETTY 234
# name BETTY
# ['234']
# phonebook {'KEVIN': ['123'], 'BETTY': ['234']}
# FIND 123
# name 123
# []
# KEVIN
# phonebook {'KEVIN': ['123'], 'BETTY': ['234']}
# FIND 234
# name 234
# []
# 234 not found
# phonebook {'KEVIN': ['123'], 'BETTY': ['234']}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-443-7d3ab950c4e8> in <module>
#      14         print(find(phonebook, name))
#      15     print('phonebook', phonebook)
# ---> 16     command = input().split()
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def addNumbers(phonebook, name, phones):
    if name not in phonebook:
        phonebook[name] = []
    phonebook[name].extend(phones)
    phonebook[name].sort()
    phonebook[name].reverse()


def show(phonebook,command, name):
    if name not in phonebook:
        print(name + ' not found')
    else:
        print (phonebook[name])


def find(phonebook, name):
    for key in phonebook:
        if name in phonebook[key]:
            return key
        return(name + ' not found')

def main():
    command = input().split() 
    phonebook = {} 

    while (command[0] != 'END'): 
        name = str(command[1])
        #print('name', name)
        phones = command[2:]
        #print(phones)
        if command[0] == 'ADD':
            addNumbers(phonebook, name, phones)
        elif command[0] == 'SHOW':
            show(phonebook, command, name)
        elif command[0] == 'FIND':
            print(find(phonebook, name))
        #print('phonebook', phonebook)
        command = input().split()
        
main()
# Out:
# ADD ADA 123
# ADD BETTY 234
# FIND 123
# ADA
# FIND 234
# 234 not found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-439-d6d9fa9a700f> in <module>
#      38         command = input().split()
#      39
# ---> 40 main()
#
# <ipython-input-439-d6d9fa9a700f> in main()
#      36             print(find(phonebook, name))
#      37         #print('phonebook', phonebook)
# ---> 38         command = input().split()
#      39
#      40 main()
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
