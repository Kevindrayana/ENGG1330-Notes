# %%
# line function to print a line
def line(iterable, board_list, board_num):
    for num in board_num:
        if num == '':
            continue
            
        for i in iterable:
            
            for j in range(2,-1,-1):
                if str(board_num[j]).isdecimal():
                    x = j
                    break
            
            if (num == x) and (i == 2 or i == 5 or i == 8):
                print(board_list[num][i], end = '\n')
            elif i == 2 or i == 5 or i == 8:
                print(board_list[num][i], end = '  ')
            else:
                print(board_list[num][i], end = ' ')
            
            
# board function to print the board
def board(board_list, board_marker):
## printing the board marker
    for i in range(len(board_marker)):
        
        for j in range(2,-1,-1):
                if str(board_num[j]).isdecimal():
                    x = j
                    break
                    
        if i != x and board_marker[i] != '':
            print(f'{board_marker[i]:<7}', end = '')
        else:
            print(board_marker[i],end = '')
    print()
    line((0,1,2), board_list, board_num)
    line((3,4,5), board_list, board_num)
    line((6,7,8), board_list, board_num)

    
# change board list function to mutate the board_list in a given index to X    
def change_board_list(move, board_list):
    if move[0] == 'A':
        board_list[0][int(move[1])] = 'X'
    elif move[0] == 'B':
        board_list[1][int(move[1])] = 'X'
    elif move[0] == 'C':
        board_list[2][int(move[1])] = 'X'
        

# delete board_function to delete part of a board which is dead
def delete_board(index):
    board_list[index] = ['', '', '', '', '', '', '', '', '']
    board_marker[index] = ''
    board_num[index] = ''
    
    
# check win function to specify winning conditions
def check_win(board_list, board_num):
    for i in board_num:
        if i != '':
            if (board_list[i][0] == board_list[i][1] == board_list[i][2] == 'X'  or board_list[i][3] == board_list[i][4] == board_list[i][5] == 'X' or board_list[i][6] == board_list[i][7] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][3] == board_list[i][6] == 'X' or board_list[i][1] == board_list[i][4] == board_list[i][7] == 'X' or board_list[i][2] == board_list[i][5] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][4] == board_list[i][8] == 'X' or board_list[i][6] == board_list[i][4] == board_list[i][2] == 'X'):
                delete_board(i)
                return True
        

# check input invalidity 
def input_check(move,used_move,board_marker):
    if move not in ('A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8'):
        return True
    if move in used_move:
        return True
    if move[0] not in board_marker:
        return True
    

def knight_move(move):
    move_num = int(move[1])
    if move_num == 0 or move_num == 1:
        move_num1 = move_num + 5
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list, board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 7
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list, board_num):
            pass
        else:
            return move
        
    elif move_num == 2:
        move_num1 = move_num + 1
        move = move[0] + str(move_num1)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 5
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move

    elif move_num == 3:
        move_num1 = move_num - 1
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 5
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
    elif move_num == 5:
        move_num1 = move_num - 5
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 1
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
    elif move_num == 6:
        move_num1 = move_num - 5
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num - 1
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
    elif move_num == 7 or move_num == 8:
        move_num1 = move_num - 7
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num - 5
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move


def scissors_move(board_list):
    for i in range(3):
        if board_list[i][1] == 'X' and board_list[i][3] == 'X' and board_list[i][8] != 'X': 
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
        elif board_list[i][1] == 'X' and board_list[i][3] != 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 2:
                return 'C3'
        elif board_list[i][1] != 'X' and board_list[i][3] == 'X' and board_list[i][8] == 'X': 
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
        elif board_list[i][1] == 'X' and board_list[i][5] == 'X' and board_list[i][6] != 'X': 
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
        elif board_list[i][1] == 'X' and board_list[i][5] != 'X' and board_list[i][6] == 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
        elif board_list[i][1] != 'X' and board_list[i][5] == 'X' and board_list[i][6] == 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
        elif board_list[i][3] == 'X' and board_list[i][7] == 'X' and board_list[i][2] != 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
        elif board_list[i][3] == 'X' and board_list[i][7] != 'X' and board_list[i][2] == 'X':
            if i == 0:
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
        elif board_list[i][7] != 'X' and board_list[i][5] == 'X' and board_list[i][0] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
        elif board_list[i][0] == 'X' and board_list[i][5] == 'X' and board_list[i][7] != 'X': 
            if i == 0:
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
        elif board_list[i][0] == 'X' and board_list[i][5] != 'X' and board_list[i][7] == 'X': 
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
        elif board_list[i][0] != 'X' and board_list[i][5] == 'X' and board_list[i][7] == 'X': 
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
    
def count_x_in_centre(board_list):
    counter = []
    for i in board_list:
        if i[4] == 'X':
            counter += True
            
    return counter


def sacrifice_if_there_is_x_in_centre(board_list):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
            
        elif board_list[i][1] == 'X' and board_list[i][4] == 'X':
            if i == 0: 
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
            
        elif board_list[i][2] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
            
        elif board_list[i][3] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
            
        elif board_list[i][5] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 3:
                return 'C3'
        
        elif board_list[i][6] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
        
        elif board_list[i][7] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
        
        elif board_list[i][8] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
    
    
def sacrifice_if_no_x_in_centre(board_list):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][1] == 'X' and board_list[i][2] != 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 3:
                return 'C2'
        elif board_list[i][0] == 'X' and board_list[i][1] != 'X' and board_list[i][2] == 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 3:
                return 'C1'
        elif board_list[i][0] != 'X' and board_list[i][1] == 'X' and board_list[i][2] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 3:
                return 'C0'
            
        elif board_list[i][0] == 'X' and board_list[i][3] == 'X' and board_list[i][6] != 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 3:
                return 'C6'
        elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and board_list[i][6] == 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 3:
                return 'C3'
        elif board_list[i][0] != 'X' and board_list[i][3] == 'X' and board_list[i][6] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 3:
                return 'C0'
            
        elif board_list[i][2] == 'X' and board_list[i][5] == 'X' and board_list[i][8] != 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 3:
                return 'C8'
        elif board_list[i][2] == 'X' and board_list[i][5] != 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 3:
                return 'C5'
        elif board_list[i][2] != 'X' and board_list[i][5] == 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 3:
                return 'C2'
            
        elif board_list[i][6] == 'X' and board_list[i][7] == 'X' and board_list[i][8] != 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 3:
                return 'C8'
        elif board_list[i][6] == 'X' and board_list[i][7] != 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 3:
                return 'C7'
        elif board_list[i][6] != 'X' and board_list[i][7] == 'X' and board_list[i][8] == 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 3:
                return 'C6'
        else:
            pass

        
def board_count(board_num):
    counter = 0
    for i in board_num:
        if i == '':
            continue
        else:
            counter += 1
    return counter
            
            
def ai():
    if board_num != [0,'',''] or board_num == ['',1,''] or board_num == ['','',2]:
        if move_count == 0:
            return 'A4'

        if move_count == 1 and move[0] == 'A':
            return sacrifice_if_there_is_x_in_centre(board_list) 
        if move_count == 1 and move[0] == 'B':
            return 'C4'
        if move_count == 1 and move[0] == 'C':
            return 'B4'
            
   
        if type(sacrifice_if_there_is_x_in_centre(board_list)) != None:
            return sacrifice_if_there_is_x_in_centre(board_list)
        if type(sacrifice_if_no_x_in_centre(board_list)) != None:
            return sacrifice_if_no_x_in_centre(board_list)
    else:
        print(move)
        return knight_move(move)

# %%
def oneboard(board_list):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][1] != 'X':
            if i == 0:
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
        if board_list[i][0] == 'X' and board_list[i][3] != 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
            
        if board_list[i][1] == 'X' and board_list[i][2] != 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
        if board_list[i][1] == 'X' and board_list[i][0] != 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
            
        if board_list[i][2] == 'X' and board_list[i][1] != 'X':
            if i == 0:
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
        if board_list[i][2] == 'X' and board_list[i][5] != 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 2:
                return 'C3'
            
        if board_list[i][3] == 'X' and board_list[i][0] != 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
        if board_list[i][3] == 'X' and board_list[i][6] != 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
            
        if board_list[i][5] == 'X' and board_list[i][2] != '2':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
        if board_list[i][5] == 'X' and board_list[i][2] != '8':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
            
        if board_list[i][6] == 'X' and board_list[i][3] != 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
        if board_list[i][6] == 'X' and board_list[i][7] != 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
            
        if board_list[i][7] == 'X' and board_list[i][6] != 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
        if board_list[i][7] == 'X' and board_list[i][8] != 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'
            
        if board_list[i][8] == 'X' and board_list[i][7] != 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
        if board_list[i][8] == 'X' and board_list[i][5] != 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 2:
                return 'C3'

            
def twoboard():
    pass

##used move, count_x_in_centre
def threeboard():
    if move_count == 0:
        return 'A4'

    if move_count == 1 and move[0] == 'A':
        return sacrifice_if_there_is_x_in_centre(board_list) 
    if move_count == 1 and move[0] == 'B':
        return 'C4'
    if move_count == 1 and move[0] == 'C':
        return 'B4'

    if used_move[-1][0] = 'A' and move_count == 2:
        sacrifice_if_there_is_x_in_centre():
# Out:
#   File "<ipython-input-137-0a32d6183d82>", line 139
#     if used_move[-1][0] = 'A' and move_count == 2:
#                         ^
# SyntaxError: invalid syntax

# %%
board_list = []
for _ in range(3):
    board_list.append([num for num in range(9)])
    
board_marker = ['A', 'B', 'C']

board_num = [0,1,2]

used_move = []
    
move_count = 0

### MAIN ###
while True:
    
    # player 1 move
    board(board_list, board_marker)
    
    while True:
        
        if board_count(board_num) == 3:
            move = threeboard()
        elif board_count(board_num) == 2:
            move = twoboard()
        elif board_count(board_num) == 1:
            move = oneboard()
        
        print('PLAYER 1: ' + move)
        if input_check(move,used_move,board_marker):
            print('Invalid move, please input again')
        else:
            used_move.append(move)
            move_count += 1
            break
            
    change_board_list(move, board_list)
    
    check_win(board_list, board_num, board_count)
    
    print(f'board_list: {board_list}')
    print(f'board_num: {board_num}' )
    print(f'used_move: {used_move}')
    print(board_count(board_num))
    
    if board_list == [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]:
        print('Player 2 wins game')
        break
    
    # player 2 move
    board(board_list, board_marker)
    
    while True:
        move = input("Player 2: ")
        if input_check(move,used_move,board_marker):
            print('Invalid move, please input again')
        else:
            used_move.append(move)
            break
            
    change_board_list(move, board_list)
    
    check_win(board_list, board_num, board_count)
    
    print(f'board_list: {board_list}')
    print(f'board_num: {board_num}' )
    print(f'used_move: {used_move}')
    print(board_count(board_num))
    
    if board_list == [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]:
        print('Player 1 wins game')
        break
# Out:
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 4 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# PLAYER 1: A4
# board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4']
# 3
# A      B      C
# 0 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# Player 2: A0
# board_list: [['X', 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
# board_num: [0, 1, 2]
# used_move: ['A4', 'A0']
# 3
# A      B      C
# X 1 2  0 1 2  0 1 2
# 3 X 5  3 4 5  3 4 5
# 6 7 8  6 7 8  6 7 8
# PLAYER 1: A8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-6473e9f52df1> in <module>
#      36     change_board_list(move, board_list)
#      37
# ---> 38     check_win(board_list, board_num, board_count)
#      39
#      40     print(f'board_list: {board_list}')
#
# <ipython-input-120-52be77b6021f> in check_win(board_list, board_num, board_count)
#      63             if (board_list[i][0] == board_list[i][1] == board_list[i][2] == 'X'  or board_list[i][3] == board_list[i][4] == board_list[i][5] == 'X' or board_list[i][6] == board_list[i][7] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][3] == board_list[i][6] == 'X' or board_list[i][1] == board_list[i][4] == board_list[i][7] == 'X' or board_list[i][2] == board_list[i][5] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][4] == board_list[i][8] == 'X' or board_list[i][6] == board_list[i][4] == board_list[i][2] == 'X'):
#      64                 delete_board(i)
# ---> 65                 board_count -= 1
#      66                 return True
#      67
#
# TypeError: unsupported operand type(s) for -=: 'function' and 'int'

# %%
board_list = [['X', 'X', 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
board_num = [0,1,2]
if check_win(board_list,board_num):
    print('yes')
    
else:
    print('no')
# Out:
# no

# %%
board_list = [[0, 'X', 2, 'X', 4, 5, 6, 7, 'X'], [0, 'X', 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
board_marker = ['A', 'B', 'C']
scissors_move(board_list)
# Out:
# 'B8'

# %%
board_list = [['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 'X', 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
scissors_move(board_list)
# Out:
# 'B8'

# %%
board_list = [['X', 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
sacrifice_if_there_is_x_in_centre(board_list)
# Out:
# 'A8'

# %%
board_list = [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 'X'], ['X', 1, 2, 3, 'X', 5, 6, 7, 8]]
sacrifice_if_there_is_x_in_centre(board_list)

# %%
board_list = [[0, 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 'X'], ['X', 1, 2, 3, 'X', 5, 6, 7, 8]]
print(board_list[2][8])
for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                print( 'A0')
            elif i == 1:
                print( 'B0')
            elif i == 2:
                print( 'C0')
# Out:
# 8
# C0

# %%
move = 'B0'
knight_move(move)
# Out:
# 'B5'

# %%
def knight_move(move):
    move_num = int(move[1])
    if move_num == 0 or move_num == 1:
        move_num1 = move_num + 5
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list, board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 7
        move = move[0] + str(move_num2)
        if move_num2 not in range(0,9) or check_win(board_list,board_num):
            pass
        else:
            return move
        
    elif move_num == 2:
        move_num1 = move_num + 1
        move = move[0] + str(move_num1)
        print(check_win(board_list, board_num))
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 5
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move

    elif move_num == 3:
        move_num1 = move_num - 1
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 5
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
    elif move_num == 5:
        move_num1 = move_num - 5
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num + 1
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
    elif move_num == 6:
        move_num1 = move_num - 5
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num - 1
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
    elif move_num == 7 or move_num == 8:
        move_num1 = move_num - 7
        move = move[0] + str(move_num1) 
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
        move_num2 = move_num - 5
        move = move[0] + str(move_num2)
        if input_check(move,used_move,board_marker) or check_win(board_list,board_num):
            pass
        else:
            return move
        
board_list = [['X', 1, 'X', 3, 'X', 'X', 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
board_num = [0, '', '']

knight_move('A6')

# %%
def check_win(board_list, board_num):
    for i in board_num:
        if i != '':
            if (board_list[i][0] == board_list[i][1] == board_list[i][2] == 'X'  or board_list[i][3] == board_list[i][4] == board_list[i][5] == 'X' or board_list[i][6] == board_list[i][7] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][3] == board_list[i][6] == 'X' or board_list[i][1] == board_list[i][4] == board_list[i][7] == 'X' or board_list[i][2] == board_list[i][5] == board_list[i][8] == 'X' or board_list[i][0] == board_list[i][4] == board_list[i][8] == 'X' or board_list[i][6] == board_list[i][4] == board_list[i][2] == 'X'):
                delete_board(i)
                return True
def knight_move(move):
    move_num = int(move[1])
    if move_num == 0 or move_num == 1:
        move_num1 = move_num + 5
        move = move[0] + str(move_num1)
        change_board_list(move, board_list)
        
        
        if not input_check(move,used_move,board_marker) or not check_win(board_list, board_num):
            return move
        
        move_num2 = move_num + 7
        move = move[0] + str(move_num2)
        if not input_check(move,used_move,board_marker) or not check_win(board_list, board_num):
            return move
        
board_list = [['X', 1, 'X', 3, 'X', 'X', 6, 7, 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
board_num = [0, '', '']
board(board_list,board_marker)
knight_move('A1')
# Out:
# X 1 X
# 3 X X
# 6 7 8
# 'A8'

# %%
def board_count(board_num):
    counter = 0
    for i in board_num:
        if i == '':
            continue
        else:
            counter += 1
    return counter

board_num = ['', 1, 2]
print(board_count(board_num))
# Out:
# 2

# %%
if i == ['', '', '', '', '', '', '', '', '']:
            continue
        elif i[4] == 'X':
            counter.append(True)
        elif i[4] == '':
            counter.append(False)

# %%
'''center_x_list =  count_x_in_centre(board_list)
        
            
    if move[0] == 'A':
        mymove = 0
    elif move[0] == 'B':
        mymove = 1
    else:
        mymove = 2
    
    if sacrifice_if_no_x_in_centre(board_list) != None and counter_x_list[mymove] == False:
        return sacrifice_if_no_x_in_centre(board_list)
    if sacrifice_if_there_is_x_in_centre(board_list) != None and counter_x_list[mymove] == False:
        return sacrifice_if_there_is_x_in_centre(board_list)
    
    
    
    true_counter = 0
    for i in count_x_in_centre(board_list):
        if i == True:
            true_counter += 1
    
    if true_counter <= 1:
        if move[0] == 'C':
            return "B4"
        
        elif move[0] == 'B':
            return "C4"
'''

# %%
board_list =  [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]
sacrifice_if_there_is_x_in_centre(board_list)
# Out:
# 'B8'

# %%
def count_x_in_centre(board_list):
    counter = []
    for i in board_list:
        if i == ['', '', '', '', '', '', '', '', '']:
            pass
        elif i[4] != 'X':
            counter.append(False)
        elif i[4] == 'X':
            counter.append(True)
    return counter

# %%
def twoboard(used_move):
    if count_x_in_centre(board_list).count("True") <= 1:
        if move[0] == 'C' and 'B4' not in used_move:
            return "B4"
        elif move[0] == 'B' and 'C4' not in used_move:
            return "C4"
    
    if count_x_in_centre(board_list) == [True, True]:
        if board_count(board_num) >1:
            return sacrifice_if_there_is_x_in_centre(board_list)
        elif board_count(board_num) == 1:
            return oneboard(board_list, used_move)

# %%
board_list = [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 'X', 5, 6, 7, 8], [0, 1, 2, 3, 'X', 5, 6, 7, 8]]

# %%
twoboard(used_move)
# Out:
# 'B8'

# %%
def oneboard(board_list, used_move):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][3] != 'X':
            if i == 0 and 'A5' not in used_move:
                return 'A5 '
            elif i == 1 and 'B5' not in used_move:
                return 'B5'
            elif i == 2 and 'C5' not in used_move:
                return 'C5'
        if board_list[i][2] == 'X' and board_list[i][5] != 'X':
            if i == 0 and 'A3' not in used_move:
                return 'A3'
            elif i == 1 and 'B3' not in used_move:
                return 'B3'
            elif i == 2 and 'C3' not in used_move:
                return 'C3'
        if board_list[i][6] == 'X' and board_list[i][3] != 'X':
            if i == 0 and 'A5' not in used_move:
                return 'A5'
            elif i == 1 and 'B5' not in used_move:
                return 'B5'
            elif i == 2 and 'C5' not in used_move:
                return 'C5'
                    
used_move = ['A4', 'A0', 'A8', 'B4', 'C4', 'C0', 'C8', 'B0', 'B7', 'B2']
board_list = [['', '', '', '', '', '', '', '', ''], ['X', 1, 'X', 3, 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', '']]
    
oneboard(board_list, used_move)
# Out:
# 'B5'

# %%
def oneboard(board_list, used_move):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][1] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A7' not in used_move:
                return 'A7'
            elif i == 1 and 'B7' not in used_move:
                return 'B7'
            elif i == 2 and 'C7' not in used_move:
                return 'C7'
        if board_list[i][0] == 'X' and board_list[i][3] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A5' not in used_move:
                return 'A5 '
            elif i == 1 and 'B5' not in used_move:
                return 'B5'
            elif i == 2 and 'C5' not in used_move:
                return 'C5'
            
        if board_list[i][1] == 'X' and board_list[i][2] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A6' not in used_move:
                return 'A6'
            elif i == 1 and 'B6' not in used_move:
                return 'B6'
            elif i == 2 and 'C6' not in used_move:
                return 'C6'
        if board_list[i][1] == 'X' and board_list[i][0] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A8' not in used_move:
                return 'A8'
            elif i == 1 and 'B8' not in used_move:
                return 'B8'
            elif i == 2 and 'C8' not in used_move:
                return 'C8'
            
        if board_list[i][2] == 'X' and board_list[i][1] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A7' not in used_move:
                return 'A7'
            elif i == 1 and 'B7' not in used_move:
                return 'B7'
            elif i == 2 and 'C7' not in used_move:
                return 'C7'
        if board_list[i][2] == 'X' and board_list[i][5] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A3' not in used_move:
                return 'A3'
            elif i == 1 and 'B3' not in used_move:
                return 'B3'
            elif i == 2 and 'C3' not in used_move:
                return 'C3'
            
        if board_list[i][3] == 'X' and board_list[i][0] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A8' not in used_move:
                return 'A8'
            elif i == 1 and 'B8' not in used_move:
                return 'B8'
            elif i == 2 and 'C8' not in used_move:
                return 'C8'
        if board_list[i][3] == 'X' and board_list[i][6] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A2' not in used_move:
                return 'A2'
            elif i == 1 and 'B2' not in used_move:
                return 'B2'
            elif i == 2 and 'C2' not in used_move:
                return 'C2'
            
        if board_list[i][5] == 'X' and board_list[i][2] != '2' and board_list[i][4] == 'X':
            if i == 0 and 'A6' not in used_move:
                return 'A6'
            elif i == 1 and 'B6' not in used_move:
                return 'B6'
            elif i == 2 and 'C6' not in used_move:
                return 'C6'
        if board_list[i][5] == 'X' and board_list[i][2] != '8' and board_list[i][4] == 'X':
            if i == 0 and 'A0' not in used_move:
                return 'A0'
            elif i == 1 and 'B0' not in used_move:
                return 'B0'
            elif i == 2 and 'C0' not in used_move:
                return 'C0'
            
        if board_list[i][6] == 'X' and board_list[i][3] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A5' not in used_move:
                return 'A5'
            elif i == 1 and 'B5' not in used_move:
                return 'B5'
            elif i == 2 and 'C5' not in used_move:
                return 'C5'
        if board_list[i][6] == 'X' and board_list[i][7] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A1' not in used_move:
                return 'A1'
            elif i == 1 and 'B1' not in used_move:
                return 'B1'
            elif i == 2 and 'C1' not in used_move:
                return 'C1'
            
        if board_list[i][7] == 'X' and board_list[i][6] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A2' not in used_move:
                return 'A2'
            elif i == 1 and 'B2' not in used_move:
                return 'B2'
            elif i == 2 and 'C2' not in used_move:
                return 'C2'
        if board_list[i][7] == 'X' and board_list[i][8] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A0' not in used_move:
                return 'A0'
            elif i == 1 and 'B0' not in used_move:
                return 'B0'
            elif i == 2 and 'C0' not in used_move:
                return 'C0'
            
        if board_list[i][8] == 'X' and board_list[i][7] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A1' not in used_move:
                return 'A1'
            elif i == 1 and 'B1' not in used_move:
                return 'B1'
            elif i == 2 and 'C1' not in used_move:
                return 'C1'
        if board_list[i][8] == 'X' and board_list[i][5] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A3' not in used_move:
                return 'A3'
            elif i == 1 and 'B3' not in used_move:
                return 'B3'
            elif i == 2 and 'C3' not in used_move:
                return 'C3'

# %%
board_list = [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 4, 5, 6, 7, 8], ['X', 1, 2, 3, 'X', 5, 6, 7, 8]]

# %%
used_move=['A4', 'A0', 'A8', 'B3', 'C4', 'C0']

# %%
oneboard(board_list,used_move)
# Out:
# 'C7'

# %%
for i in range(len(board_list)):
    if board_list[i] == [0, 1, 2, 3, 4, 5, 6, 7, 8]:
        if i == 0:
            return 'A4'
        elif i == 1:
            return 'B4'
        else:
            return 'C4'
# Out:
#   File "<ipython-input-159-d142fecdf5d6>", line 4
#     return 'A4'
#     ^
# SyntaxError: 'return' outside function

# %%
move = 'B1'
used_move = ['A4', 'B3', 'C4', 'C0', 'C8', 'A3', 'A8', 'B1']
board_list = [[0, 1, 2, 'X', 'X', 5, 6, 7, 'X'], [0, 'X', 2, 'X', 4, 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
def twoboard(used_move):
    for i in range(len(board_list)):
        if board_list[i] == [0, 1, 2, 3, 4, 5, 6, 7, 8]:
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            else:
                return 'C4'

    if count_x_in_centre(board_list) == [True, True]:
        if board_count(board_num) >1:
            return sacrifice_if_there_is_x_in_centre(board_list)
        elif board_count(board_num) == 1:
            return oneboard(board_list, used_move)

    else:
        # play in the one with center x
        if 'B4' in used_move:
            print('hi')
            return oneboard(board_list, used_move)
        # play in the one with no center x
        else:
            if sacrifice_if_no_x_in_centre(board_list) != None:
                return sacrifice_if_no_x_in_centre(board_list)
            else:
                return scissors_move(board_list)
        
twoboard(used_move)
# Out:
# 'A1'

# %%
board_list = [[0, 1, 2, 'X', 'X', 5, 6, 7, 'X'], [0, 'X', 2, 'X', 4, 5, 6, 7, 8], ['', '', '', '', '', '', '', '', '']]
scissors_move(board_list)
# Out:
# 'A1'

# %%
def scissors_move(board_list):
    for i in range(3):
        if board_list[i][4] != 'X':
            if board_list[i][1] == 'X' and board_list[i][3] == 'X' and board_list[i][8] != 'X': 
                if i == 0:
                    return 'A8'
                elif i == 1:
                    return 'B8'
                elif i == 2:
                    return 'C8'
            elif board_list[i][1] == 'X' and board_list[i][3] != 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A3'
                elif i == 1:
                    return 'B3'
                elif i == 2:
                    return 'C3'
            elif board_list[i][1] != 'X' and board_list[i][3] == 'X' and board_list[i][8] == 'X': 
                if i == 0:
                    return 'A1'
                elif i == 1:
                    return 'B1'
                elif i == 2:
                    return 'C1'
            elif board_list[i][1] == 'X' and board_list[i][5] == 'X' and board_list[i][6] != 'X': 
                if i == 0:
                    return 'A6'
                elif i == 1:
                    return 'B6'
                elif i == 2:
                    return 'C6'
            elif board_list[i][1] == 'X' and board_list[i][5] != 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A5'
                elif i == 1:
                    return 'B5'
                elif i == 2:
                    return 'C5'
            elif board_list[i][1] != 'X' and board_list[i][5] == 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A1'
                elif i == 1:
                    return 'B1'
                elif i == 2:
                    return 'C1'
            elif board_list[i][3] == 'X' and board_list[i][7] == 'X' and board_list[i][2] != 'X':
                if i == 0:
                    return 'A2'
                elif i == 1:
                    return 'B2'
                elif i == 2:
                    return 'C2'
            elif board_list[i][3] == 'X' and board_list[i][7] != 'X' and board_list[i][2] == 'X':
                if i == 0:
                    return 'A7'
                elif i == 1:
                    return 'B7'
                elif i == 2:
                    return 'C7'
            elif board_list[i][7] != 'X' and board_list[i][5] == 'X' and board_list[i][0] == 'X':
                if i == 0:
                    return 'A0'
                elif i == 1:
                    return 'B0'
                elif i == 2:
                    return 'C0'
            elif board_list[i][0] == 'X' and board_list[i][5] == 'X' and board_list[i][7] != 'X': 
                if i == 0:
                    return 'A7'
                elif i == 1:
                    return 'B7'
                elif i == 2:
                    return 'C7'
            elif board_list[i][0] == 'X' and board_list[i][5] != 'X' and board_list[i][7] == 'X': 
                if i == 0:
                    return 'A5'
                elif i == 1:
                    return 'B5'
                elif i == 2:
                    return 'C5'
            elif board_list[i][0] != 'X' and board_list[i][5] == 'X' and board_list[i][7] == 'X': 
                if i == 0:
                    return 'A0'
                elif i == 1:
                    return 'B0'
                elif i == 2:
                    return 'C0'
                
scissors_move(board_list)
# Out:
# 'B8'

# %%
def f(board_list, used_move):
    if board_list[i][8] == 'X' and board_list[i][5] != 'X' and board_list[i][4] == 'X':
                if i == 0 and 'A3' not in used_move:
                    return 'A3'
                elif i == 1 and 'B3' not in used_move:
                    return 'B3'
                elif i == 2 and 'C3' not in used_move:
                    return 'C3'
board_list = board_list: [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 'X', 5, 6, 'X', 'X']]
board_num: ['', '', 2]
used_move: ['A4', 'B2', 'C4', 'A8', 'A0', 'B6', 'B4', 'C3', 'C8', 'C7']
move_count: 5
[True]
1
C
0 1 2
X X 5
6 X X
Player 1: None
# Out:
#   File "<ipython-input-173-f32c3b701f6e>", line 3
#     return 'A3'
#     ^
# SyntaxError: 'return' outside function

# %%
board_list = [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 'X', 'X', 5, 6, 'X', 'X']]

for i in range(3):
    if board_list[i][3] == 'X' and board_list[i][6] != 'X' and board_list[i][4] == 'X':
        if i == 0 and 'A2' not in used_move:
            print( 'A2')
        elif i == 1 and 'B2' not in used_move:
            print( 'B2')
        elif i == 2 and 'C2' not in used_move:
            print( 'C2')
# Out:
# C2

# %%
def sacrifice_if_there_is_x_in_centre(board_list):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A8'
            elif i == 1:
                return 'B8'
            elif i == 2:
                return 'C8'
            
        elif board_list[i][1] == 'X' and board_list[i][4] == 'X':
            if i == 0: 
                return 'A7'
            elif i == 1:
                return 'B7'
            elif i == 2:
                return 'C7'
            
        elif board_list[i][2] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A6'
            elif i == 1:
                return 'B6'
            elif i == 2:
                return 'C6'
            
        elif board_list[i][3] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A5'
            elif i == 1:
                return 'B5'
            elif i == 2:
                return 'C5'
            
        elif board_list[i][5] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A3'
            elif i == 1:
                return 'B3'
            elif i == 2:
                return 'C3'
        
        elif board_list[i][6] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A2'
            elif i == 1:
                return 'B2'
            elif i == 2:
                return 'C2'
        
        elif board_list[i][7] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A1'
            elif i == 1:
                return 'B1'
            elif i == 2:
                return 'C1'
        
        elif board_list[i][8] == 'X' and board_list[i][4] == 'X':
            if i == 0:
                return 'A0'
            elif i == 1:
                return 'B0'
            elif i == 2:
                return 'C0'

# %%
board_list: [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 'X', 6, 7, 8]]
board_num: [0, '', 2]
used_move: ['A4', 'B8', 'C4', 'B2', 'B5', 'C5']
move_count: 3
[True, True]
2
A      C
0 1 2  0 1 2
3 X 5  3 X X
6 7 8  6 7 8

# %%
board_list = [[0, 1, 2, 3, 'X', 5, 6, 7, 8], ['', '', '', '', '', '', '', '', ''], [0, 1, 'X', 3, 4, 5, 6, 'X', 8]]

count_x_in_centre(board_list)
# Out:
# [True, False]

# %%
sacrifice_if_no_x_in_centre(board_list)

# %%
scissors_move(board_list)

# %%
board_list = [['X', 1, 'X', 3, 'X', 5, 6, 'X', 8], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]

# %%
for i in range(3):
    if board_list[i][0] == 'X' and board_list[i][3] != 'X' and board_list[i][4] == 'X':
        print(i)
# Out:
# 0

# %%
def one_board(move, board_list, used_move):
    board_alphabet = move[0]
    if board_alphabet == 'A':
        i = 0
    elif board_alphabet == 'B':
        i = 1
    elif board_alphabet == 'C':
        i = 2

    if board_list[i][4] == 'X':
        if (board_list[i][0] == 'X') and (board_list[i][1] != 'X') and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][1] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][1] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][2] == 'X' and board_list[i][1] != 'X' and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][2] == 'X' and board_list[i][5] != 'X'and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'

        if board_list[i][3] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'
        elif board_list[i][3] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][5] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][5] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'

        if board_list[i][6] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][6] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][7] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'
        elif board_list[i][7] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'

        if board_list[i][8] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][8] == 'X' and board_list[i][5] != 'X' and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'

    for j in range(3):
        if board_list[j][4] != 'X' and board_list[j] != ['', '', '', '', '', '', '', '', '']:
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            else:
                return 'C4'
            
board_list = [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 'X', 2, 3, 4, 'X', 'X', 7, 8]]
used_move = ['A4', 'C1', 'B4', 'A0', 'A8', 'B8', 'B1', 'C6', 'C5', 'B3', 'B6', 'B7']

# %%
oneboard(board_list,used_move)
# Out:
# 'C4'

# %%
'A7' not in used_move
# Out:
# False

# %%
if False:
    print('yes')

# %%
#revise!!
def oneboard(board_list, used_move):
    for i in range(3):
        if board_list[i][0] == 'X' and board_list[i][1] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A7' not in used_move:
                return 'A7'
            elif i == 1 and 'B7' not in used_move:
                return 'B7'
            elif i == 2 and 'C7' not in used_move:
                return 'C7'
        elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A5' not in used_move:
                return 'A5 '
            elif i == 1 and 'B5' not in used_move:
                return 'B5'
            elif i == 2 and 'C5' not in used_move:
                return 'C5'
            
        elif board_list[i][1] == 'X' and board_list[i][2] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A6' not in used_move:
                return 'A6'
            elif i == 1 and 'B6' not in used_move:
                return 'B6'
            elif i == 2 and 'C6' not in used_move:
                return 'C6'
        elif board_list[i][1] == 'X' and board_list[i][0] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A8' not in used_move:
                return 'A8'
            elif i == 1 and 'B8' not in used_move:
                return 'B8'
            elif i == 2 and 'C8' not in used_move:
                return 'C8'
            
        elif board_list[i][2] == 'X' and board_list[i][1] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A7' not in used_move:
                return 'A7'
            elif i == 1 and 'B7' not in used_move:
                return 'B7'
            elif i == 2 and 'C7' not in used_move:
                return 'C7'
        elif board_list[i][2] == 'X' and board_list[i][5] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A3' not in used_move:
                return 'A3'
            elif i == 1 and 'B3' not in used_move:
                return 'B3'
            elif i == 2 and 'C3' not in used_move:
                return 'C3'
            
        elif board_list[i][3] == 'X' and board_list[i][0] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A8' not in used_move:
                return 'A8'
            elif i == 1 and 'B8' not in used_move:
                return 'B8'
            elif i == 2 and 'C8' not in used_move:
                return 'C8'
        elif board_list[i][3] == 'X' and board_list[i][6] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A2' not in used_move:
                return 'A2'
            elif i == 1 and 'B2' not in used_move:
                return 'B2'
            elif i == 2 and 'C2' not in used_move:
                return 'C2'
            
        elif board_list[i][5] == 'X' and board_list[i][2] != '2' and board_list[i][4] == 'X':
            if i == 0 and 'A6' not in used_move:
                return 'A6'
            elif i == 1 and 'B6' not in used_move:
                return 'B6'
            elif i == 2 and 'C6' not in used_move:
                return 'C6'
        elif board_list[i][5] == 'X' and board_list[i][2] != '8' and board_list[i][4] == 'X':
            if i == 0 and 'A0' not in used_move:
                return 'A0'
            elif i == 1 and 'B0' not in used_move:
                return 'B0'
            elif i == 2 and 'C0' not in used_move:
                return 'C0'
            
        elif board_list[i][6] == 'X' and board_list[i][3] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A5' not in used_move:
                return 'A5'
            elif i == 1 and 'B5' not in used_move:
                return 'B5'
            elif i == 2 and 'C5' not in used_move:
                return 'C5'
        elif board_list[i][6] == 'X' and board_list[i][7] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A1' not in used_move:
                return 'A1'
            elif i == 1 and 'B1' not in used_move:
                return 'B1'
            elif i == 2 and 'C1' not in used_move:
                return 'C1'
            
        elif board_list[i][7] == 'X' and board_list[i][6] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A2' not in used_move:
                return 'A2'
            elif i == 1 and 'B2' not in used_move:
                return 'B2'
            elif i == 2 and 'C2' not in used_move:
                return 'C2'
        elif board_list[i][7] == 'X' and board_list[i][8] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A0' not in used_move:
                return 'A0'
            elif i == 1 and 'B0' not in used_move:
                return 'B0'
            elif i == 2 and 'C0' not in used_move:
                return 'C0'
            
        elif board_list[i][8] == 'X' and board_list[i][7] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A1' not in used_move:
                return 'A1'
            elif i == 1 and 'B1' not in used_move:
                return 'B1'
            elif i == 2 and 'C1' not in used_move:
                return 'C1'
        elif board_list[i][8] == 'X' and board_list[i][5] != 'X' and board_list[i][4] == 'X':
            if i == 0 and 'A3' not in used_move:
                return 'A3'
            elif i == 1 and 'B3' not in used_move:
                return 'B3'
            elif i == 2 and 'C3' not in used_move:
                return 'C3'
            
        elif board_list[i][4] != 'X' and board_list[i] != ['', '', '', '', '', '', '', '', '']:
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            else:
                return 'C4'

# %%
def one_board(board_list, used_move):
    my_dict = {0: 'A', 1: 'B', 2: 'C'}
    for i in range(3):
        if board_list[i][4] == 'X':
            
            if (board_list[i][0] == 'X') and (board_list[i][1] != 'X') and ((my_dict[i]+'7') not in used_move):
                return my_dict[i] + '7'
            elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
                return my_dict[i] + '5'

            if board_list[i][1] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
                return my_dict[i] + '6'
            elif board_list[i][1] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
                return my_dict[i] + '8'
            
            if board_list[i][2] == 'X' and board_list[i][1] != 'X' and ((my_dict[i]+'7') not in used_move):
                return my_dict[i] + '7'
            elif board_list[i][2] == 'X' and board_list[i][5] != 'X'and ((my_dict[i]+'3') not in used_move):
                return my_dict[i] + '3'
            
            if board_list[i][3] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
                return my_dict[i] + '2'
            elif board_list[i][3] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
                return my_dict[i] + '8'
            
            if board_list[i][5] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
                return my_dict[i] + '6'
            elif board_list[i][5] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
                return my_dict[i] + '0'
            
            if board_list[i][6] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
                return my_dict[i] + '1'
            elif board_list[i][6] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
                return my_dict[i] + '5'
            
            if board_list[i][7] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
                return my_dict[i] + '0'
            elif board_list[i][7] == 'X' and board_list[i][6] != 'X': and ((my_dict[i]+'2') not in used_move)
                return my_dict[i] + '2'
            
            if board_list[i][8] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
                return my_dict[i] + '1'
            elif board_list[i][8] == 'X' and board_list[i][5] != 'X' and ((my_dict[i]+'3') not in used_move):
                return my_dict[i] + '3'
            
        elif board_list[i][4] != 'X' and board_list[i] != ['', '', '', '', '', '', '', '', '']:
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            else:
                return 'C4'
# Out:
#   File "<ipython-input-254-1f6bb4554273>", line 38
#     elif board_list[i][7] == 'X' and board_list[i][6] != 'X': and ((my_dict[i]+'2') not in used_move)
#                                                               ^
# SyntaxError: invalid syntax

# %%
def sacrifice_if_no_x_in_centre(board_list):
    for i in range(3):
        if board_list[i][4] != 'X':
            if board_list[i][0] == 'X' and board_list[i][1] == 'X' and board_list[i][2] != 'X':
                if i == 0:
                    return 'A2'
                elif i == 1:
                    return 'B2'
                elif i == 2:
                    return 'C2'
            elif board_list[i][0] == 'X' and board_list[i][1] != 'X' and board_list[i][2] == 'X':
                if i == 0:
                    return 'A1'
                elif i == 1:
                    return 'B1'
                elif i == 2:
                    return 'C1'
            elif board_list[i][0] != 'X' and board_list[i][1] == 'X' and board_list[i][2] == 'X':
                if i == 0:
                    return 'A0'
                elif i == 1:
                    return 'B0'
                elif i == 2:
                    return 'C0'

            elif board_list[i][0] == 'X' and board_list[i][3] == 'X' and board_list[i][6] != 'X':
                if i == 0:
                    return 'A6'
                elif i == 1:
                    return 'B6'
                elif i == 2:
                    return 'C6'
            elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A3'
                elif i == 1:
                    return 'B3'
                elif i == 2:
                    return 'C3'
            elif board_list[i][0] != 'X' and board_list[i][3] == 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A0'
                elif i == 1:
                    return 'B0'
                elif i == 2:
                    return 'C0'

            elif board_list[i][2] == 'X' and board_list[i][5] == 'X' and board_list[i][8] != 'X':
                if i == 0:
                    return 'A8'
                elif i == 1:
                    return 'B8'
                elif i == 2:
                    return 'C8'
            elif board_list[i][2] == 'X' and board_list[i][5] != 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A5'
                elif i == 1:
                    return 'B5'
                elif i == 2:
                    return 'C5'
            elif board_list[i][2] != 'X' and board_list[i][5] == 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A2'
                elif i == 1:
                    return 'B2'
                elif i == 2:
                    return 'C2'

            elif board_list[i][6] == 'X' and board_list[i][7] == 'X' and board_list[i][8] != 'X':
                if i == 0:
                    return 'A8'
                elif i == 1:
                    return 'B8'
                elif i == 2:
                    return 'C8'
            elif board_list[i][6] == 'X' and board_list[i][7] != 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A7'
                elif i == 1:
                    return 'B7'
                elif i == 2:
                    return 'C7'
            elif board_list[i][6] != 'X' and board_list[i][7] == 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A6'
                elif i == 1:
                    return 'B6'
                elif i == 2:
                    return 'C6'

            elif board_list[i][1] == 'X' and board_list[i][4] != 'X' and board_list[i][7] == 'X':
                if i == 0:
                    return 'A4'
                elif i == 1:
                    return 'B4'
                elif i == 2:
                    return 'C4'

            elif board_list[i][3] == 'X' and board_list[i][4] != 'X' and board_list[i][5] == 'X':
                if i == 0:
                    return 'A4'
                elif i == 1:
                    return 'B4'
                elif i == 2:
                    return 'C4'

            elif board_list[i][0] == 'X' and board_list[i][4] != 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A4'
                elif i == 1:
                    return 'B4'
                elif i == 2:
                    return 'C4'   

            elif board_list[i][2] == 'X' and board_list[i][4] != 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A4'
                elif i == 1:
                    return 'B4'
                elif i == 2:
                    return 'C4'

# %%
def twoboard(used_move):

    for i in range(len(board_list)):
        if board_list[i] == [0, 1, 2, 3, 4, 5, 6, 7, 8]:
            if i == 0:
                return 'A4'
            elif i == 1:
                return 'B4'
            else:
                return 'C4'
    
    if count_x_in_centre(board_list) == [True, True]:
        mylist = make_board_for_sacrifice(move, board_list)
        if sacrifice_if_there_is_x_in_centre (mylist)!= None:
            return sacrifice_if_there_is_x_in_centre(mylist)
        #elif board_count(board_num) == 1:
            #return oneboard(board_list, used_move)
        
    elif count_x_in_centre(board_list) == [True, False] or count_x_in_centre(board_list) == [False, True]:
        # play in the one with center x
        if move[0] + '4' in used_move:
            return oneboard(board_list, used_move)
        # play in the one with no center x
        else:
            new_board = []
            for i in board_list:
                if i[4] != 'X':
                    new_board.append(i)
                elif i[4] == 'X':
                    new_board.append(['', '', '', '', '', '', '', '', ''])
                    
            if sacrifice_if_no_x_in_centre(new_board) != None:
                return sacrifice_if_no_x_in_centre(new_board)
            else:
                return scissors_move(board_list)

# %%
move = 'C4'
board_list = [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 'X', 'X', 'X', 7, 8], [0, 'X', 2, 3, 'X', 'X', 'X', 7, 8]]
used_move = ['A4', 'A8', 'A0', 'C1', 'B4', 'B5', 'B6', 'C5', 'C6', 'C4']
make_board_for_sacrifice(move, board_list)

twoboard(used_move)
# Out:
# 2
# 2
# 'C7'

# %%
board_list = [['', '', '', '', '', '', '', '', ''], ['X', 1, 2, 3, 4, 'X', 6, 7, 8], [0, 1, 'X', 'X', 'X', 5, 6, 'X', 'X']]used_move = ['A4', 'A1', 'A7', 'B0', 'C4', 'C2', 'C7', 'C8', 'C3', 'B5']

for i in range(3):
    if board_list[i][0] == 'X' and board_list[i][5] == 'X' and board_list[i][7] != 'X': 
        if i == 0:
            print ('A7')
        elif i == 1:
            print ('B7')
        elif i == 2:
            print ('C7')
# Out:
# B7

# %%
def scissors_move(board_list):
    for i in range(3):
        if board_list[i][4] != 'X' and board_list[i] != ['', '', '', '', '', '', '', '', '']:
            if board_list[i][1] == 'X' and board_list[i][3] == 'X' and board_list[i][8] != 'X': 
                if i == 0:
                    return 'A8'
                elif i == 1:
                    return 'B8'
                elif i == 2:
                    return 'C8'
            elif board_list[i][1] == 'X' and board_list[i][3] != 'X' and board_list[i][8] == 'X':
                if i == 0:
                    return 'A3'
                elif i == 1:
                    return 'B3'
                elif i == 2:
                    return 'C3'
            elif board_list[i][1] != 'X' and board_list[i][3] == 'X' and board_list[i][8] == 'X': 
                if i == 0:
                    return 'A1'
                elif i == 1:
                    return 'B1'
                elif i == 2:
                    return 'C1'
            elif board_list[i][1] == 'X' and board_list[i][5] == 'X' and board_list[i][6] != 'X': 
                if i == 0:
                    return 'A6'
                elif i == 1:
                    return 'B6'
                elif i == 2:
                    return 'C6'
            elif board_list[i][1] == 'X' and board_list[i][5] != 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A5'
                elif i == 1:
                    return 'B5'
                elif i == 2:
                    return 'C5'
            elif board_list[i][1] != 'X' and board_list[i][5] == 'X' and board_list[i][6] == 'X':
                if i == 0:
                    return 'A1'
                elif i == 1:
                    return 'B1'
                elif i == 2:
                    return 'C1'
            elif board_list[i][3] == 'X' and board_list[i][7] == 'X' and board_list[i][2] != 'X':
                if i == 0:
                    return 'A2'
                elif i == 1:
                    return 'B2'
                elif i == 2:
                    return 'C2'
            elif board_list[i][3] == 'X' and board_list[i][7] != 'X' and board_list[i][2] == 'X':
                if i == 0:
                    return 'A7'
                elif i == 1:
                    return 'B7'
                elif i == 2:
                    return 'C7'
            elif board_list[i][3] != 'X' and board_list[i][7] == 'X' and board_list[i][2] == 'X':
                if i == 0:
                    return 'A3'
                elif i == 1:
                    return 'B3'
                elif i == 2:
                    return 'C3'
            elif board_list[i][0] == 'X' and board_list[i][5] == 'X' and board_list[i][7] != 'X': 
                if i == 0:
                    return 'A7'
                elif i == 1:
                    return 'B7'
                elif i == 2:
                    return 'C7'
            elif board_list[i][0] == 'X' and board_list[i][5] != 'X' and board_list[i][7] == 'X': 
                if i == 0:
                    return 'A5'
                elif i == 1:
                    return 'B5'
                elif i == 2:
                    return 'C5'
            elif board_list[i][0] != 'X' and board_list[i][5] == 'X' and board_list[i][7] == 'X': 
                if i == 0:
                    return 'A0'
                elif i == 1:
                    return 'B0'
                elif i == 2:
                    return 'C0'

# %%
scissors_move(board_list)
# Out:
# 'B7'

# %%
sacrifice_if_no_x_in_centre(new_board)

# %%
twoboard(used_move)
# Out:
# 'B7'

# %%
def oneboard(board_list, used_move):
    board_alphabet = move[0]
    i = ''
    if board_alphabet == 'A':
        i = 0
    elif board_alphabet == 'B':
        i = 1
    elif board_alphabet == 'C':
        i = 2
    
    my_dict = {0: 'A', 1: 'B', 2: 'C'}
    
    if board_list[i][4] == 'X':

        if (board_list[i][0] == 'X') and (board_list[i][1] != 'X') and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][1] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][1] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][2] == 'X' and board_list[i][1] != 'X' and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][2] == 'X' and board_list[i][5] != 'X'and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'

        if board_list[i][3] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'
        elif board_list[i][3] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][5] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][5] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'

        if board_list[i][6] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][6] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][7] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'
        elif board_list[i][7] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'

        if board_list[i][8] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][8] == 'X' and board_list[i][5] != 'X' and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'
        
    for j in range(3):
        if board_list[j][4] != 'X' and board_list[j] != ['', '', '', '', '', '', '', '', '']:
            if j == 0:
                return 'A4'
            elif j == 1:
                return 'B4'
            else:
                return 'C4'

# %%
board_list = [['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 7, 'X'], ['', '', '', '', '', '', '', '', '']]
used_move = ['A4', 'B8', 'C4', 'A2', 'A6', 'C2', 'C7', 'C1']
oneboard(board_list, used_move)
# Out:
# 'B4'

# %%
# ['A4', 'C6', 'B4', 'A5', 'A3', 'B2', 'B7', 'B6', 'C4', 'C3', 'C8', 'C1']

# %%
def oneboard(board_list, used_move):
    
    board_alphabet = move[0]
    if board_alphabet == 'A':
        i = 0
    elif board_alphabet == 'B':
        i = 1
    elif board_alphabet == 'C':
        i = 2

    my_dict = {0: 'A', 1: 'B', 2: 'C'}

    if board_list[i][4] == 'X':

        if (board_list[i][0] == 'X') and (board_list[i][1] != 'X') and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][0] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][1] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][1] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][2] == 'X' and board_list[i][1] != 'X' and ((my_dict[i]+'7') not in used_move):
            return my_dict[i] + '7'
        elif board_list[i][2] == 'X' and board_list[i][5] != 'X'and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'

        if board_list[i][3] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'
        elif board_list[i][3] == 'X' and board_list[i][0] != 'X' and ((my_dict[i]+'8') not in used_move):
            return my_dict[i] + '8'

        if board_list[i][5] == 'X' and board_list[i][2] != 'X' and ((my_dict[i]+'6') not in used_move):
            return my_dict[i] + '6'
        elif board_list[i][5] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'

        if board_list[i][6] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][6] == 'X' and board_list[i][3] != 'X' and ((my_dict[i]+'5') not in used_move):
            return my_dict[i] + '5'

        if board_list[i][7] == 'X' and board_list[i][8] != 'X' and ((my_dict[i]+'0') not in used_move):
            return my_dict[i] + '0'
        elif board_list[i][7] == 'X' and board_list[i][6] != 'X' and ((my_dict[i]+'2') not in used_move):
            return my_dict[i] + '2'

        if board_list[i][8] == 'X' and board_list[i][7] != 'X' and ((my_dict[i]+'1') not in used_move):
            return my_dict[i] + '1'
        elif board_list[i][8] == 'X' and board_list[i][5] != 'X' and ((my_dict[i]+'3') not in used_move):
            return my_dict[i] + '3'
    for i in range(3):
        if board_list[i][4] != 'X' and board_list[i] != ['', '', '', '', '', '', '', '', '']:
            if board_list[i][0] == 'X' and board_list[i][8] != 'X':
                return my_dict[i] + '8'
            elif board_list[i][1] == 'X' and board_list[i][7] != 'X':
                return my_dict[i] + '7'
            elif board_list[i][2] == 'X'and board_list[i][6] != 'X':
                return my_dict[i] + '6'
            elif board_list[i][3] == 'X'and board_list[i][5] != 'X':
                return my_dict[i] + '5'
            elif board_list[i][4] == 'X'and board_list[i][4] != 'X':
                return my_dict[i] + '4'
            elif board_list[i][5] == 'X'and board_list[i][3] != 'X':
                return my_dict[i] + '3'
            elif board_list[i][6] == 'X'and board_list[i][2] != 'X':
                return my_dict[i] + '2'
            elif board_list[i][7] == 'X'and board_list[i][1] != 'X':
                return my_dict[i] + '1'
            elif board_list[i][8] == 'X'and board_list[i][0] != 'X':
                return my_dict[i] + '0'

# %%
board_list = [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], [0, 1, 2, 3, 4, 5, 6, 'X', 8]]

# %%
used_move: ['A4', 'C7', 'B4', 'A5', 'A3', 'B0', 'B7', 'B8']

# %%
move = 'B8'

# %%
oneboard(board_list,used_move)
# Out:
# 'C1'
